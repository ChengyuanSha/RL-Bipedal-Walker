# %% [markdown]
# Author: Chengyuan Sha
#
# Reference:
# Borrowed some ideas such as Open AI's actor-critic normalization tricks:
# https://github.com/pytorch/examples/blob/main/reinforcement_learning/actor_critic.py
# PPO formular and explanation:
# https://jonathan-hui.medium.com/rl-trust-region-policy-optimization-trpo-explained-a6ee04eeeee9
# OpenAI blog and github:
# https://openai.com/blog/openai-baselines-ppo/
# https://github.com/openai/baselines
# https://spinningup.openai.com/en/latest/algorithms/ppo.html

# %%
import numpy as np
import torch
import torch.nn as nn
import gym

# %%
seed = 100
torch.manual_seed(seed)
np.random.seed(seed)

# %%
# setting up GPU
try:
    device = torch.device("cuda")
    print("Current using GPU: ")
    print(torch.cuda.get_device_name(device))
except:
    print("GPU not connected. Please check your CUDA and required packages.")
# Out:
# Current using GPU:
# NVIDIA GeForce RTX 3090

# %%
class Buffer:
    """ replay buffer keep track of all variables needed for PPO """
    def __init__(self):
        self.actions = []
        self.states = []
        self.log_probability = []
        self.rewards = []
        self.is_finish = []

    def delete_all(self):
        del self.actions[:]
        del self.states[:]
        del self.log_probability[:]
        del self.rewards[:]
        del self.is_finish[:]

def MLP(state_dim, output_dim, hidden_dim = 64):
    """ define MLP for actor critic """
    return nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim),
            )

class AC(nn.Module):
    """ Actor Critic """
    def __init__(self, state_dim, action_dim):
        super(AC, self).__init__()
        self.action_dim = action_dim
        self.action_var = torch.full((action_dim,), 0.3).to(device) # 0.36 is the standard deviation
        self.actor = MLP(state_dim, action_dim)
        self.critic = MLP(state_dim, 1)

    def get_distribution(self, M, covariantM):
        return torch.distributions.MultivariateNormal(M, covariantM)

    def AC_action(self, state):
        distribution = self.get_distribution(self.actor(state), torch.diag(self.action_var).unsqueeze(dim=0))
        action = distribution.sample().detach()
        action_logprob = distribution.log_prob(action).detach()
        return action, action_logprob

    def AC_evaluate(self, state, action):
        action_mean = self.actor(state)
        covariantM = torch.diag_embed(self.action_var.expand_as(action_mean)).to(device)
        distribution = self.get_distribution(action_mean, covariantM)
        return distribution.log_prob(action), self.critic(state), distribution.entropy() # log_probability, state values, entropy


class PPO:
    """ Main PPO class """
    def __init__(self, state_dim, action_dim, lr_actor, lr_critic, gamma, num_of_epochs):
        self.gamma = gamma
        self.num_of_epochs = num_of_epochs
        self.buffer = Buffer()
        self.policy = AC(state_dim, action_dim).to(device)
        self.optimizer = torch.optim.Adam([
            {'params': self.policy.actor.parameters(), 'lr': lr_actor},
            {'params': self.policy.critic.parameters(), 'lr': lr_critic}
        ])
        self.policy_old = AC(state_dim, action_dim).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())

    def choose_action(self, state):
        with torch.no_grad():
            state = torch.FloatTensor(state).to(device)
            action, action_logprob = self.policy_old.AC_action(state)

        self.buffer.states.append(state)
        self.buffer.actions.append(action)
        self.buffer.log_probability.append(action_logprob)

        return action.detach().cpu().numpy().flatten()

    @staticmethod
    def normalize(reward):
        """ Reference:  Open AI's actor-critic Trick """
        rewards = torch.tensor(reward, dtype=torch.float32).to(device)
        return (rewards - rewards.mean()) / (rewards.std() + 1e-7)

    def monte_carlo_estimation(self):
        """ monte carlo estimation """
        rewards = []
        gamma_reward = 0
        for reward, is_finish in zip(self.buffer.rewards[::-1], self.buffer.is_finish[::-1]):
            if is_finish:
                gamma_reward = 0
            gamma_reward = reward + (self.gamma * gamma_reward)
            rewards.append(gamma_reward)
        return rewards[::-1]

    @staticmethod
    def get_tensor(tensor):
        return torch.squeeze(torch.stack(tensor, dim=0)).detach().to(device)

    def update_PPO(self):
        rewards = self.monte_carlo_estimation()
        # Open AI's actor-critic Normalizing Trick
        rewards = PPO.normalize(rewards)
        past_states, past_actions, past_logprobs = PPO.get_tensor(self.buffer.states), PPO.get_tensor(self.buffer.actions), PPO.get_tensor(self.buffer.log_probability)
        # Main update loop according to the pseudocode formula
        for _ in range(self.num_of_epochs):
            log_probability, state_values, entropy = self.policy.AC_evaluate(past_states, past_actions)
            state_values = torch.squeeze(state_values)
            ratios = torch.exp(log_probability - past_logprobs.detach())
            # Surrogate Loss calculation
            advantages = rewards - state_values.detach()
            surrogate_loss1 = ratios * advantages
            surrogate_loss2 = torch.clamp(ratios, 0.8, 1.2) * advantages # clip the loss
            # computed the total loss
            loss = -torch.min(surrogate_loss1, surrogate_loss2) + 0.5 * nn.MSELoss()(state_values, rewards) - 0.01 * entropy
            # gradient optimization
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
        # cleaning and reinit
        self.policy_old.load_state_dict(self.policy.state_dict())
        self.buffer.delete_all()

    def save_model(self, save_path):
        """ save model to pth file """
        torch.save(self.policy_old.state_dict(), save_path)

# %% [markdown]
# Setting hyperparameters & gym environment

# %%
# hyper parameters
hp = {'max_ep_len': 1000, 'max_steps': 4000000,
      'action_std':0.6, 'action_std_decay_rate': 0.05,  'min_action_std':0.1,
      'update_step': 4000, 'num_of_epochs': 80,  'gamma': 0.99,
      'lr_actor': 0.0003, 'lr_critic':0.001 }

# %%
# creating bipedal walker environment
env = gym.make('BipedalWalker-v3')

# %%
# state
state_dim = env.observation_space.shape[0]
# action
action_dim = env.action_space.shape[0]

hp['action_dim'] = action_dim
hp['state_dim'] = state_dim

# %%
action_dim
# Out:
# 4

# %% [markdown]
# Training PPO:

# %%
def train(hp):
    # logging file
    file_log = open('PPO_record.csv',"w+")
    file_log.write('episode,step,reward\n')
    # init PPO agent
    ppo = PPO(hp['state_dim'], hp['action_dim'], hp['lr_actor'], hp['lr_critic'], hp['gamma'],
              hp['num_of_epochs'])
    # init recording variables
    reward_logging, episode_logging, step, episode = 0, 0, 0, 0

    # main training loop
    while step <= hp['max_steps']:
        state = env.reset()
        reward_cur_episode = 0
        for _ in range(1, hp['max_ep_len']+1):
            action = ppo.choose_action(state)
            state, reward, is_finish, extra_info = env.step(action)
            # append to record buffer
            ppo.buffer.rewards.append(reward)
            ppo.buffer.is_finish.append(is_finish)
            step +=1
            reward_cur_episode += reward
            if step % hp['update_step'] == 0:
                ppo.update_PPO() # update PPO
            if step % 3000 == 0: # log & print training info
                avg_reward = round(reward_logging / episode_logging, 4)
                to_print = '{},{},{}\n'.format(episode, step, avg_reward)
                print("Episode : {} \t Step : {} \t Average Reward : {}".format(episode, step, avg_reward))
                file_log.write(to_print)
                file_log.flush()
                reward_logging, episode_logging = 0, 0
            if step % 200000 == 0:  # save model to pth
                ppo.save_model("trained_model.pth")
                print("Model Saved!!")
            if is_finish: # die
                break
        reward_logging += reward_cur_episode
        episode_logging += 1
        episode += 1
    # close file and environment
    file_log.close()
    env.close()

train(hp)
# Out:
# Episode : 2 	 Step : 2000 	 Average Reward : -81.1874
# Episode : 7 	 Step : 4000 	 Average Reward : -107.533
# Episode : 10 	 Step : 6000 	 Average Reward : -112.6325
# Episode : 16 	 Step : 8000 	 Average Reward : -87.197
# Episode : 23 	 Step : 10000 	 Average Reward : -92.4617
# Episode : 27 	 Step : 12000 	 Average Reward : -108.5548
# Episode : 31 	 Step : 14000 	 Average Reward : -83.6433
# Episode : 35 	 Step : 16000 	 Average Reward : -79.9456
# Episode : 38 	 Step : 18000 	 Average Reward : -70.1747
# Episode : 42 	 Step : 20000 	 Average Reward : -101.5549
# Episode : 46 	 Step : 22000 	 Average Reward : -87.2885
# Episode : 48 	 Step : 24000 	 Average Reward : -52.5491
# Episode : 50 	 Step : 26000 	 Average Reward : -47.9675
# Episode : 53 	 Step : 28000 	 Average Reward : -72.0272
# Episode : 57 	 Step : 30000 	 Average Reward : -86.4033
# Episode : 61 	 Step : 32000 	 Average Reward : -80.2197
# Episode : 64 	 Step : 34000 	 Average Reward : -75.5797
# Episode : 66 	 Step : 36000 	 Average Reward : -54.5517
# Episode : 68 	 Step : 38000 	 Average Reward : -56.5083
# Episode : 70 	 Step : 40000 	 Average Reward : -50.5628
# Episode : 72 	 Step : 42000 	 Average Reward : -49.7714
# Episode : 74 	 Step : 44000 	 Average Reward : -63.2395
# Episode : 77 	 Step : 46000 	 Average Reward : -90.7984
# Episode : 79 	 Step : 48000 	 Average Reward : -48.6534
# Episode : 82 	 Step : 50000 	 Average Reward : -65.4159
# Episode : 84 	 Step : 52000 	 Average Reward : -46.3038
# Episode : 86 	 Step : 54000 	 Average Reward : -39.9911
# Episode : 88 	 Step : 56000 	 Average Reward : -52.7469
# Episode : 90 	 Step : 58000 	 Average Reward : -46.0732
# Episode : 94 	 Step : 60000 	 Average Reward : -80.1316
# Episode : 96 	 Step : 62000 	 Average Reward : -47.0011
# Episode : 98 	 Step : 64000 	 Average Reward : -47.2943
# Episode : 100 	 Step : 66000 	 Average Reward : -45.1056
# Episode : 102 	 Step : 68000 	 Average Reward : -46.6267
# Episode : 104 	 Step : 70000 	 Average Reward : -43.4294
# Episode : 106 	 Step : 72000 	 Average Reward : -45.5154
# Episode : 108 	 Step : 74000 	 Average Reward : -45.2482
# Episode : 110 	 Step : 76000 	 Average Reward : -46.463
# Episode : 112 	 Step : 78000 	 Average Reward : -43.5222
# Episode : 114 	 Step : 80000 	 Average Reward : -41.8575
# Episode : 116 	 Step : 82000 	 Average Reward : -40.2863
# Episode : 118 	 Step : 84000 	 Average Reward : -41.3912
# Episode : 120 	 Step : 86000 	 Average Reward : -47.8771
# Episode : 122 	 Step : 88000 	 Average Reward : -44.4469
# Episode : 124 	 Step : 90000 	 Average Reward : -41.163
# Episode : 127 	 Step : 92000 	 Average Reward : -69.4952
# Episode : 129 	 Step : 94000 	 Average Reward : -44.0487
# Episode : 131 	 Step : 96000 	 Average Reward : -38.1788
# Episode : 133 	 Step : 98000 	 Average Reward : -43.1074
# Episode : 135 	 Step : 100000 	 Average Reward : -39.1883
# Episode : 137 	 Step : 102000 	 Average Reward : -39.4754
# Episode : 139 	 Step : 104000 	 Average Reward : -43.2583
# Episode : 141 	 Step : 106000 	 Average Reward : -44.5518
# Episode : 144 	 Step : 108000 	 Average Reward : -67.11
# Episode : 146 	 Step : 110000 	 Average Reward : -39.0749
# Episode : 148 	 Step : 112000 	 Average Reward : -42.3661
# Episode : 150 	 Step : 114000 	 Average Reward : -41.831
# Episode : 152 	 Step : 116000 	 Average Reward : -42.5419
# Episode : 154 	 Step : 118000 	 Average Reward : -38.736
# Episode : 156 	 Step : 120000 	 Average Reward : -42.3994
# Episode : 158 	 Step : 122000 	 Average Reward : -39.9475
# Episode : 160 	 Step : 124000 	 Average Reward : -38.0591
# Episode : 162 	 Step : 126000 	 Average Reward : -40.3505
# Episode : 164 	 Step : 128000 	 Average Reward : -41.647
# Episode : 166 	 Step : 130000 	 Average Reward : -39.8404
# Episode : 168 	 Step : 132000 	 Average Reward : -37.3497
# Episode : 170 	 Step : 134000 	 Average Reward : -39.9895
# Episode : 172 	 Step : 136000 	 Average Reward : -39.7158
# Episode : 174 	 Step : 138000 	 Average Reward : -40.4397
# Episode : 176 	 Step : 140000 	 Average Reward : -44.8525
# Episode : 178 	 Step : 142000 	 Average Reward : -36.3951
# Episode : 180 	 Step : 144000 	 Average Reward : -37.8625
# Episode : 182 	 Step : 146000 	 Average Reward : -34.332
# Episode : 184 	 Step : 148000 	 Average Reward : -36.9328
# Episode : 186 	 Step : 150000 	 Average Reward : -35.5866
# Episode : 189 	 Step : 152000 	 Average Reward : -65.4433
# Episode : 192 	 Step : 154000 	 Average Reward : -61.1521
# Episode : 194 	 Step : 156000 	 Average Reward : -36.9539
# Episode : 196 	 Step : 158000 	 Average Reward : -31.0805
# Episode : 198 	 Step : 160000 	 Average Reward : -35.044
# Episode : 200 	 Step : 162000 	 Average Reward : -36.2542
# Episode : 202 	 Step : 164000 	 Average Reward : -35.6035
# Episode : 204 	 Step : 166000 	 Average Reward : -36.0708
# Episode : 206 	 Step : 168000 	 Average Reward : -33.0559
# Episode : 208 	 Step : 170000 	 Average Reward : -32.8346
# Episode : 210 	 Step : 172000 	 Average Reward : -30.3242
# Episode : 212 	 Step : 174000 	 Average Reward : -31.4415
# Episode : 214 	 Step : 176000 	 Average Reward : -37.5965
# Episode : 216 	 Step : 178000 	 Average Reward : -32.8223
# Episode : 218 	 Step : 180000 	 Average Reward : -26.2179
# Episode : 220 	 Step : 182000 	 Average Reward : -35.0578
# Episode : 222 	 Step : 184000 	 Average Reward : -33.1374
# Episode : 224 	 Step : 186000 	 Average Reward : -30.8604
# Episode : 226 	 Step : 188000 	 Average Reward : -29.3907
# Episode : 228 	 Step : 190000 	 Average Reward : -20.5358
# Episode : 230 	 Step : 192000 	 Average Reward : -20.5679
# Episode : 232 	 Step : 194000 	 Average Reward : -25.8813
# Episode : 234 	 Step : 196000 	 Average Reward : -22.1354
# Episode : 236 	 Step : 198000 	 Average Reward : -19.185
# Episode : 238 	 Step : 200000 	 Average Reward : -19.6815
# Model Saved!!
# Episode : 240 	 Step : 202000 	 Average Reward : -17.3326
# Episode : 242 	 Step : 204000 	 Average Reward : -17.2112
# Episode : 244 	 Step : 206000 	 Average Reward : -13.2524
# Episode : 246 	 Step : 208000 	 Average Reward : -11.0626
# Episode : 248 	 Step : 210000 	 Average Reward : -11.8388
# Episode : 250 	 Step : 212000 	 Average Reward : -11.76
# Episode : 252 	 Step : 214000 	 Average Reward : -5.7909
# Episode : 254 	 Step : 216000 	 Average Reward : -18.3733
# Episode : 256 	 Step : 218000 	 Average Reward : 1.5607
# Episode : 259 	 Step : 220000 	 Average Reward : -39.218
# Episode : 261 	 Step : 222000 	 Average Reward : -3.4971
# Episode : 263 	 Step : 224000 	 Average Reward : -7.7889
# Episode : 265 	 Step : 226000 	 Average Reward : 7.0169
# Episode : 267 	 Step : 228000 	 Average Reward : 2.5112
# Episode : 269 	 Step : 230000 	 Average Reward : 4.075
# Episode : 271 	 Step : 232000 	 Average Reward : -4.3607
# Episode : 273 	 Step : 234000 	 Average Reward : 4.8528
# Episode : 275 	 Step : 236000 	 Average Reward : -0.6583
# Episode : 277 	 Step : 238000 	 Average Reward : -4.3576
# Episode : 279 	 Step : 240000 	 Average Reward : 6.5789
# Episode : 281 	 Step : 242000 	 Average Reward : 13.7108
# Episode : 283 	 Step : 244000 	 Average Reward : 12.8174
# Episode : 285 	 Step : 246000 	 Average Reward : 9.1198
# Episode : 287 	 Step : 248000 	 Average Reward : 9.5105
# Episode : 289 	 Step : 250000 	 Average Reward : 17.0624
# Episode : 291 	 Step : 252000 	 Average Reward : 24.148
# Episode : 293 	 Step : 254000 	 Average Reward : 24.3995
# Episode : 295 	 Step : 256000 	 Average Reward : 21.4646
# Episode : 297 	 Step : 258000 	 Average Reward : 29.4542
# Episode : 299 	 Step : 260000 	 Average Reward : 24.0462
# Episode : 301 	 Step : 262000 	 Average Reward : 32.8308
# Episode : 303 	 Step : 264000 	 Average Reward : 22.6195
# Episode : 305 	 Step : 266000 	 Average Reward : 25.6606
# Episode : 307 	 Step : 268000 	 Average Reward : 30.7294
# Episode : 309 	 Step : 270000 	 Average Reward : 27.1521
# Episode : 312 	 Step : 272000 	 Average Reward : -41.0687
# Episode : 314 	 Step : 274000 	 Average Reward : 25.9172
# Episode : 316 	 Step : 276000 	 Average Reward : 29.0012
# Episode : 318 	 Step : 278000 	 Average Reward : 42.039
# Episode : 320 	 Step : 280000 	 Average Reward : 32.1919
# Episode : 322 	 Step : 282000 	 Average Reward : 44.4834
# Episode : 324 	 Step : 284000 	 Average Reward : 30.8689
# Episode : 326 	 Step : 286000 	 Average Reward : 41.4842
# Episode : 328 	 Step : 288000 	 Average Reward : 37.5442
# Episode : 330 	 Step : 290000 	 Average Reward : 31.8459
# Episode : 332 	 Step : 292000 	 Average Reward : 41.3132
# Episode : 334 	 Step : 294000 	 Average Reward : 49.991
# Episode : 336 	 Step : 296000 	 Average Reward : 36.5588
# Episode : 338 	 Step : 298000 	 Average Reward : 47.4178
# Episode : 340 	 Step : 300000 	 Average Reward : -31.6805
# Episode : 342 	 Step : 302000 	 Average Reward : 37.2313
# Episode : 344 	 Step : 304000 	 Average Reward : 43.2822
# Episode : 346 	 Step : 306000 	 Average Reward : 52.7446
# Episode : 348 	 Step : 308000 	 Average Reward : 50.9544
# Episode : 351 	 Step : 310000 	 Average Reward : -4.0572
# Episode : 353 	 Step : 312000 	 Average Reward : 39.8429
# Episode : 355 	 Step : 314000 	 Average Reward : 53.5255
# Episode : 357 	 Step : 316000 	 Average Reward : 45.8441
# Episode : 359 	 Step : 318000 	 Average Reward : 38.5125
# Episode : 361 	 Step : 320000 	 Average Reward : 47.7033
# Episode : 363 	 Step : 322000 	 Average Reward : 54.0331
# Episode : 365 	 Step : 324000 	 Average Reward : 49.2222
# Episode : 367 	 Step : 326000 	 Average Reward : 48.8001
# Episode : 370 	 Step : 328000 	 Average Reward : 6.8492
# Episode : 372 	 Step : 330000 	 Average Reward : 46.1173
# Episode : 374 	 Step : 332000 	 Average Reward : 39.9494
# Episode : 376 	 Step : 334000 	 Average Reward : 59.9003
# Episode : 378 	 Step : 336000 	 Average Reward : 47.7157
# Episode : 381 	 Step : 338000 	 Average Reward : 1.3873
# Episode : 383 	 Step : 340000 	 Average Reward : -77.1105
# Episode : 385 	 Step : 342000 	 Average Reward : 56.6932
# Episode : 388 	 Step : 344000 	 Average Reward : 2.1646
# Episode : 390 	 Step : 346000 	 Average Reward : 50.779
# Episode : 392 	 Step : 348000 	 Average Reward : -10.7923
# Episode : 394 	 Step : 350000 	 Average Reward : 46.6796
# Episode : 396 	 Step : 352000 	 Average Reward : 52.1076
# Episode : 398 	 Step : 354000 	 Average Reward : 55.7737
# Episode : 400 	 Step : 356000 	 Average Reward : 47.1525
# Episode : 403 	 Step : 358000 	 Average Reward : -4.4074
# Episode : 406 	 Step : 360000 	 Average Reward : 4.911
# Episode : 408 	 Step : 362000 	 Average Reward : 45.9676
# Episode : 410 	 Step : 364000 	 Average Reward : 45.6714
# Episode : 412 	 Step : 366000 	 Average Reward : 53.8549
# Episode : 414 	 Step : 368000 	 Average Reward : 48.0722
# Episode : 418 	 Step : 370000 	 Average Reward : -52.7236
# Episode : 420 	 Step : 372000 	 Average Reward : 46.3955
# Episode : 422 	 Step : 374000 	 Average Reward : 46.7982
# Episode : 424 	 Step : 376000 	 Average Reward : 45.4525
# Episode : 426 	 Step : 378000 	 Average Reward : 50.954
# Episode : 428 	 Step : 380000 	 Average Reward : 57.1596
# Episode : 430 	 Step : 382000 	 Average Reward : -12.2836
# Episode : 432 	 Step : 384000 	 Average Reward : 61.4754
# Episode : 434 	 Step : 386000 	 Average Reward : 56.8814
# Episode : 436 	 Step : 388000 	 Average Reward : 55.8757
# Episode : 438 	 Step : 390000 	 Average Reward : 54.3034
# Episode : 440 	 Step : 392000 	 Average Reward : 60.4066
# Episode : 442 	 Step : 394000 	 Average Reward : 51.3794
# Episode : 444 	 Step : 396000 	 Average Reward : 57.4934
# Episode : 446 	 Step : 398000 	 Average Reward : 55.2502
# Episode : 448 	 Step : 400000 	 Average Reward : 62.2677
# Model Saved!!
# Episode : 451 	 Step : 402000 	 Average Reward : 7.6648
# Episode : 453 	 Step : 404000 	 Average Reward : -52.8894
# Episode : 456 	 Step : 406000 	 Average Reward : 12.3888
# Episode : 459 	 Step : 408000 	 Average Reward : -0.8401
# Episode : 461 	 Step : 410000 	 Average Reward : 38.0216
# Episode : 467 	 Step : 412000 	 Average Reward : -46.0377
# Episode : 469 	 Step : 414000 	 Average Reward : 51.3426
# Episode : 471 	 Step : 416000 	 Average Reward : -14.323
# Episode : 473 	 Step : 418000 	 Average Reward : 57.6539
# Episode : 475 	 Step : 420000 	 Average Reward : 57.3458
# Episode : 478 	 Step : 422000 	 Average Reward : 15.4596
# Episode : 480 	 Step : 424000 	 Average Reward : 54.3959
# Episode : 482 	 Step : 426000 	 Average Reward : -68.5363
# Episode : 484 	 Step : 428000 	 Average Reward : 39.6484
# Episode : 487 	 Step : 430000 	 Average Reward : 11.4675
# Episode : 489 	 Step : 432000 	 Average Reward : 65.2408
# Episode : 491 	 Step : 434000 	 Average Reward : 59.4277
# Episode : 493 	 Step : 436000 	 Average Reward : 71.64
# Episode : 495 	 Step : 438000 	 Average Reward : 62.486
# Episode : 497 	 Step : 440000 	 Average Reward : 63.5177
# Episode : 499 	 Step : 442000 	 Average Reward : 57.2197
# Episode : 501 	 Step : 444000 	 Average Reward : 59.9468
# Episode : 503 	 Step : 446000 	 Average Reward : 62.8549
# Episode : 505 	 Step : 448000 	 Average Reward : 74.0964
# Episode : 507 	 Step : 450000 	 Average Reward : 70.5749
# Episode : 509 	 Step : 452000 	 Average Reward : 62.4807
# Episode : 512 	 Step : 454000 	 Average Reward : 9.9598
# Episode : 514 	 Step : 456000 	 Average Reward : 19.6012
# Episode : 516 	 Step : 458000 	 Average Reward : 56.5314
# Episode : 518 	 Step : 460000 	 Average Reward : 81.157
# Episode : 521 	 Step : 462000 	 Average Reward : 6.2339
# Episode : 523 	 Step : 464000 	 Average Reward : 51.4126
# Episode : 526 	 Step : 466000 	 Average Reward : 24.2147
# Episode : 528 	 Step : 468000 	 Average Reward : 76.4366
# Episode : 530 	 Step : 470000 	 Average Reward : 64.6584
# Episode : 532 	 Step : 472000 	 Average Reward : 68.2416
# Episode : 535 	 Step : 474000 	 Average Reward : -36.025
# Episode : 537 	 Step : 476000 	 Average Reward : 72.8318
# Episode : 539 	 Step : 478000 	 Average Reward : 66.1215
# Episode : 542 	 Step : 480000 	 Average Reward : 18.5104
# Episode : 545 	 Step : 482000 	 Average Reward : 11.4073
# Episode : 547 	 Step : 484000 	 Average Reward : 52.656
# Episode : 549 	 Step : 486000 	 Average Reward : 72.1811
# Episode : 552 	 Step : 488000 	 Average Reward : 7.8433
# Episode : 554 	 Step : 490000 	 Average Reward : 81.0208
# Episode : 556 	 Step : 492000 	 Average Reward : 63.9183
# Episode : 558 	 Step : 494000 	 Average Reward : 64.843
# Episode : 560 	 Step : 496000 	 Average Reward : 65.4875
# Episode : 562 	 Step : 498000 	 Average Reward : 82.6507
# Episode : 564 	 Step : 500000 	 Average Reward : 68.4569
# Episode : 566 	 Step : 502000 	 Average Reward : 78.2217
# Episode : 569 	 Step : 504000 	 Average Reward : 13.827
# Episode : 572 	 Step : 506000 	 Average Reward : 16.6023
# Episode : 574 	 Step : 508000 	 Average Reward : 80.637
# Episode : 577 	 Step : 510000 	 Average Reward : 16.3436
# Episode : 579 	 Step : 512000 	 Average Reward : 5.4917
# Episode : 581 	 Step : 514000 	 Average Reward : 66.7278
# Episode : 583 	 Step : 516000 	 Average Reward : 54.5707
# Episode : 585 	 Step : 518000 	 Average Reward : 81.8228
# Episode : 587 	 Step : 520000 	 Average Reward : 70.4242
# Episode : 589 	 Step : 522000 	 Average Reward : 80.6354
# Episode : 593 	 Step : 524000 	 Average Reward : -24.316
# Episode : 595 	 Step : 526000 	 Average Reward : 79.6164
# Episode : 597 	 Step : 528000 	 Average Reward : 73.9472
# Episode : 599 	 Step : 530000 	 Average Reward : 83.3718
# Episode : 603 	 Step : 532000 	 Average Reward : -55.7792
# Episode : 605 	 Step : 534000 	 Average Reward : 85.828
# Episode : 607 	 Step : 536000 	 Average Reward : 84.4377
# Episode : 609 	 Step : 538000 	 Average Reward : 75.4132
# Episode : 611 	 Step : 540000 	 Average Reward : 86.0135
# Episode : 614 	 Step : 542000 	 Average Reward : -21.0459
# Episode : 616 	 Step : 544000 	 Average Reward : 86.8382
# Episode : 619 	 Step : 546000 	 Average Reward : 23.4978
# Episode : 621 	 Step : 548000 	 Average Reward : 86.7217
# Episode : 626 	 Step : 550000 	 Average Reward : -28.2197
# Episode : 628 	 Step : 552000 	 Average Reward : 91.3563
# Episode : 631 	 Step : 554000 	 Average Reward : 19.6547
# Episode : 633 	 Step : 556000 	 Average Reward : 88.0701
# Episode : 635 	 Step : 558000 	 Average Reward : 46.2332
# Episode : 637 	 Step : 560000 	 Average Reward : 83.7488
# Episode : 639 	 Step : 562000 	 Average Reward : 79.1694
# Episode : 642 	 Step : 564000 	 Average Reward : -11.7971
# Episode : 644 	 Step : 566000 	 Average Reward : 95.7046
# Episode : 647 	 Step : 568000 	 Average Reward : 23.0204
# Episode : 649 	 Step : 570000 	 Average Reward : 85.9798
# Episode : 651 	 Step : 572000 	 Average Reward : 91.5284
# Episode : 654 	 Step : 574000 	 Average Reward : 20.5122
# Episode : 656 	 Step : 576000 	 Average Reward : 31.6001
# Episode : 658 	 Step : 578000 	 Average Reward : 97.905
# Episode : 660 	 Step : 580000 	 Average Reward : 89.8556
# Episode : 662 	 Step : 582000 	 Average Reward : 87.0675
# Episode : 665 	 Step : 584000 	 Average Reward : 28.9092
# Episode : 667 	 Step : 586000 	 Average Reward : 86.5112
# Episode : 669 	 Step : 588000 	 Average Reward : 92.6835
# Episode : 671 	 Step : 590000 	 Average Reward : 90.7168
# Episode : 673 	 Step : 592000 	 Average Reward : 89.7637
# Episode : 676 	 Step : 594000 	 Average Reward : 25.2794
# Episode : 678 	 Step : 596000 	 Average Reward : 94.2651
# Episode : 680 	 Step : 598000 	 Average Reward : 89.4078
# Episode : 682 	 Step : 600000 	 Average Reward : 90.3254
# Model Saved!!
# Episode : 684 	 Step : 602000 	 Average Reward : 85.4121
# Episode : 686 	 Step : 604000 	 Average Reward : 29.4235
# Episode : 688 	 Step : 606000 	 Average Reward : 93.4026
# Episode : 690 	 Step : 608000 	 Average Reward : 31.2631
# Episode : 692 	 Step : 610000 	 Average Reward : 97.2638
# Episode : 694 	 Step : 612000 	 Average Reward : 99.4384
# Episode : 697 	 Step : 614000 	 Average Reward : 36.3093
# Episode : 699 	 Step : 616000 	 Average Reward : 86.0145
# Episode : 702 	 Step : 618000 	 Average Reward : 46.4325
# Episode : 704 	 Step : 620000 	 Average Reward : -2.9128
# Episode : 706 	 Step : 622000 	 Average Reward : 101.703
# Episode : 708 	 Step : 624000 	 Average Reward : 96.8126
# Episode : 710 	 Step : 626000 	 Average Reward : 70.0258
# Episode : 715 	 Step : 628000 	 Average Reward : -19.1057
# Episode : 717 	 Step : 630000 	 Average Reward : 90.2139
# Episode : 719 	 Step : 632000 	 Average Reward : 96.2296
# Episode : 721 	 Step : 634000 	 Average Reward : 110.0729
# Episode : 723 	 Step : 636000 	 Average Reward : 20.9911
# Episode : 727 	 Step : 638000 	 Average Reward : -54.4204
# Episode : 730 	 Step : 640000 	 Average Reward : 18.3776
# Episode : 734 	 Step : 642000 	 Average Reward : 13.999
# Episode : 736 	 Step : 644000 	 Average Reward : 81.6428
# Episode : 739 	 Step : 646000 	 Average Reward : 37.1866
# Episode : 741 	 Step : 648000 	 Average Reward : 15.097
# Episode : 743 	 Step : 650000 	 Average Reward : 49.7219
# Episode : 745 	 Step : 652000 	 Average Reward : 83.2868
# Episode : 747 	 Step : 654000 	 Average Reward : 111.0283
# Episode : 750 	 Step : 656000 	 Average Reward : 33.9685
# Episode : 752 	 Step : 658000 	 Average Reward : 105.0693
# Episode : 754 	 Step : 660000 	 Average Reward : 62.0868
# Episode : 756 	 Step : 662000 	 Average Reward : 99.8288
# Episode : 759 	 Step : 664000 	 Average Reward : 29.7682
# Episode : 762 	 Step : 666000 	 Average Reward : 51.2153
# Episode : 764 	 Step : 668000 	 Average Reward : 90.3478
# Episode : 766 	 Step : 670000 	 Average Reward : 93.3533
# Episode : 768 	 Step : 672000 	 Average Reward : 87.8458
# Episode : 770 	 Step : 674000 	 Average Reward : 96.955
# Episode : 772 	 Step : 676000 	 Average Reward : 24.084
# Episode : 775 	 Step : 678000 	 Average Reward : -12.0928
# Episode : 777 	 Step : 680000 	 Average Reward : 96.8162
# Episode : 779 	 Step : 682000 	 Average Reward : 81.8643
# Episode : 781 	 Step : 684000 	 Average Reward : -7.8949
# Episode : 784 	 Step : 686000 	 Average Reward : 27.6459
# Episode : 786 	 Step : 688000 	 Average Reward : 100.3442
# Episode : 788 	 Step : 690000 	 Average Reward : 97.3636
# Episode : 790 	 Step : 692000 	 Average Reward : 89.8513
# Episode : 792 	 Step : 694000 	 Average Reward : 100.2281
# Episode : 794 	 Step : 696000 	 Average Reward : 98.3543
# Episode : 796 	 Step : 698000 	 Average Reward : 92.7904
# Episode : 799 	 Step : 700000 	 Average Reward : -10.8887
# Episode : 801 	 Step : 702000 	 Average Reward : 104.6319
# Episode : 804 	 Step : 704000 	 Average Reward : 14.9302
# Episode : 807 	 Step : 706000 	 Average Reward : 37.146
# Episode : 810 	 Step : 708000 	 Average Reward : 23.6344
# Episode : 812 	 Step : 710000 	 Average Reward : 34.0503
# Episode : 814 	 Step : 712000 	 Average Reward : 94.7304
# Episode : 817 	 Step : 714000 	 Average Reward : 17.2061
# Episode : 819 	 Step : 716000 	 Average Reward : 88.027
# Episode : 821 	 Step : 718000 	 Average Reward : 6.3021
# Episode : 823 	 Step : 720000 	 Average Reward : 92.4893
# Episode : 826 	 Step : 722000 	 Average Reward : -7.6228
# Episode : 828 	 Step : 724000 	 Average Reward : 94.7103
# Episode : 833 	 Step : 726000 	 Average Reward : -61.458
# Episode : 835 	 Step : 728000 	 Average Reward : 99.0251
# Episode : 837 	 Step : 730000 	 Average Reward : 92.1466
# Episode : 840 	 Step : 732000 	 Average Reward : 52.0137
# Episode : 842 	 Step : 734000 	 Average Reward : 7.6391
# Episode : 846 	 Step : 736000 	 Average Reward : -12.1181
# Episode : 848 	 Step : 738000 	 Average Reward : 26.6865
# Episode : 851 	 Step : 740000 	 Average Reward : 30.1936
# Episode : 856 	 Step : 742000 	 Average Reward : -22.5885
# Episode : 858 	 Step : 744000 	 Average Reward : 104.8252
# Episode : 862 	 Step : 746000 	 Average Reward : -14.66
# Episode : 864 	 Step : 748000 	 Average Reward : -15.8593
# Episode : 866 	 Step : 750000 	 Average Reward : 104.961
# Episode : 868 	 Step : 752000 	 Average Reward : 103.6929
# Episode : 870 	 Step : 754000 	 Average Reward : 108.4923
# Episode : 873 	 Step : 756000 	 Average Reward : 29.1148
# Episode : 876 	 Step : 758000 	 Average Reward : 32.1228
# Episode : 881 	 Step : 760000 	 Average Reward : -25.3542
# Episode : 883 	 Step : 762000 	 Average Reward : 102.0835
# Episode : 885 	 Step : 764000 	 Average Reward : 102.8358
# Episode : 889 	 Step : 766000 	 Average Reward : -8.3797
# Episode : 891 	 Step : 768000 	 Average Reward : 104.5303
# Episode : 893 	 Step : 770000 	 Average Reward : 101.5998
# Episode : 896 	 Step : 772000 	 Average Reward : -45.5101
# Episode : 899 	 Step : 774000 	 Average Reward : 33.2466
# Episode : 901 	 Step : 776000 	 Average Reward : 91.2046
# Episode : 903 	 Step : 778000 	 Average Reward : 101.9714
# Episode : 905 	 Step : 780000 	 Average Reward : 99.2291
# Episode : 907 	 Step : 782000 	 Average Reward : 100.1512
# Episode : 910 	 Step : 784000 	 Average Reward : 32.5873
# Episode : 914 	 Step : 786000 	 Average Reward : -4.4578
# Episode : 917 	 Step : 788000 	 Average Reward : 32.233
# Episode : 919 	 Step : 790000 	 Average Reward : 96.1054
# Episode : 921 	 Step : 792000 	 Average Reward : 107.9855
# Episode : 924 	 Step : 794000 	 Average Reward : 29.0315
# Episode : 926 	 Step : 796000 	 Average Reward : 94.5051
# Episode : 928 	 Step : 798000 	 Average Reward : 99.563
# Episode : 930 	 Step : 800000 	 Average Reward : -0.1216
# Model Saved!!
# Episode : 932 	 Step : 802000 	 Average Reward : 106.0366
# Episode : 935 	 Step : 804000 	 Average Reward : 62.0186
# Episode : 937 	 Step : 806000 	 Average Reward : 104.6801
# Episode : 939 	 Step : 808000 	 Average Reward : 27.1244
# Episode : 942 	 Step : 810000 	 Average Reward : 32.627
# Episode : 944 	 Step : 812000 	 Average Reward : 105.1635
# Episode : 946 	 Step : 814000 	 Average Reward : 81.9044
# Episode : 948 	 Step : 816000 	 Average Reward : 102.0337
# Episode : 952 	 Step : 818000 	 Average Reward : -6.872
# Episode : 954 	 Step : 820000 	 Average Reward : 109.3476
# Episode : 956 	 Step : 822000 	 Average Reward : 90.7547
# Episode : 958 	 Step : 824000 	 Average Reward : 106.3307
# Episode : 961 	 Step : 826000 	 Average Reward : -15.5839
# Episode : 963 	 Step : 828000 	 Average Reward : 112.2018
# Episode : 965 	 Step : 830000 	 Average Reward : 107.4635
# Episode : 967 	 Step : 832000 	 Average Reward : 114.9788
# Episode : 969 	 Step : 834000 	 Average Reward : 111.9861
# Episode : 972 	 Step : 836000 	 Average Reward : 48.4498
# Episode : 974 	 Step : 838000 	 Average Reward : 36.7477
# Episode : 976 	 Step : 840000 	 Average Reward : 47.9019
# Episode : 979 	 Step : 842000 	 Average Reward : 59.3518
# Episode : 981 	 Step : 844000 	 Average Reward : 107.4288
# Episode : 983 	 Step : 846000 	 Average Reward : 42.0703
# Episode : 985 	 Step : 848000 	 Average Reward : 35.3238
# Episode : 987 	 Step : 850000 	 Average Reward : 118.8661
# Episode : 989 	 Step : 852000 	 Average Reward : 42.9963
# Episode : 992 	 Step : 854000 	 Average Reward : 59.7437
# Episode : 994 	 Step : 856000 	 Average Reward : 105.67
# Episode : 996 	 Step : 858000 	 Average Reward : 104.9514
# Episode : 998 	 Step : 860000 	 Average Reward : 109.7088
# Episode : 1000 	 Step : 862000 	 Average Reward : 36.2609
# Episode : 1002 	 Step : 864000 	 Average Reward : 55.7008
# Episode : 1004 	 Step : 866000 	 Average Reward : 121.6282
# Episode : 1006 	 Step : 868000 	 Average Reward : 116.2308
# Episode : 1008 	 Step : 870000 	 Average Reward : 114.8639
# Episode : 1010 	 Step : 872000 	 Average Reward : 103.5452
# Episode : 1013 	 Step : 874000 	 Average Reward : 54.7977
# Episode : 1015 	 Step : 876000 	 Average Reward : 115.0399
# Episode : 1017 	 Step : 878000 	 Average Reward : 117.4468
# Episode : 1019 	 Step : 880000 	 Average Reward : 115.1076
# Episode : 1021 	 Step : 882000 	 Average Reward : 117.536
# Episode : 1023 	 Step : 884000 	 Average Reward : 102.2648
# Episode : 1025 	 Step : 886000 	 Average Reward : 111.9288
# Episode : 1028 	 Step : 888000 	 Average Reward : 38.3136
# Episode : 1030 	 Step : 890000 	 Average Reward : 110.3701
# Episode : 1032 	 Step : 892000 	 Average Reward : 107.9622
# Episode : 1034 	 Step : 894000 	 Average Reward : 102.837
# Episode : 1036 	 Step : 896000 	 Average Reward : 118.9226
# Episode : 1038 	 Step : 898000 	 Average Reward : 104.8761
# Episode : 1040 	 Step : 900000 	 Average Reward : 120.0179
# Episode : 1042 	 Step : 902000 	 Average Reward : 110.4086
# Episode : 1044 	 Step : 904000 	 Average Reward : 61.901
# Episode : 1046 	 Step : 906000 	 Average Reward : 113.9496
# Episode : 1048 	 Step : 908000 	 Average Reward : 119.1724
# Episode : 1051 	 Step : 910000 	 Average Reward : 47.1471
# Episode : 1053 	 Step : 912000 	 Average Reward : 122.7742
# Episode : 1055 	 Step : 914000 	 Average Reward : -0.1296
# Episode : 1057 	 Step : 916000 	 Average Reward : 116.8732
# Episode : 1059 	 Step : 918000 	 Average Reward : 123.4085
# Episode : 1061 	 Step : 920000 	 Average Reward : 123.0383
# Episode : 1064 	 Step : 922000 	 Average Reward : 36.9142
# Episode : 1066 	 Step : 924000 	 Average Reward : 51.3798
# Episode : 1068 	 Step : 926000 	 Average Reward : 111.087
# Episode : 1070 	 Step : 928000 	 Average Reward : 116.2257
# Episode : 1072 	 Step : 930000 	 Average Reward : 123.0918
# Episode : 1075 	 Step : 932000 	 Average Reward : 46.7641
# Episode : 1077 	 Step : 934000 	 Average Reward : 113.5633
# Episode : 1081 	 Step : 936000 	 Average Reward : 2.6815
# Episode : 1083 	 Step : 938000 	 Average Reward : 112.5271
# Episode : 1085 	 Step : 940000 	 Average Reward : 127.5003
# Episode : 1087 	 Step : 942000 	 Average Reward : 119.2779
# Episode : 1089 	 Step : 944000 	 Average Reward : 114.5316
# Episode : 1091 	 Step : 946000 	 Average Reward : 114.6917
# Episode : 1093 	 Step : 948000 	 Average Reward : 56.5811
# Episode : 1096 	 Step : 950000 	 Average Reward : 47.0297
# Episode : 1098 	 Step : 952000 	 Average Reward : 123.3801
# Episode : 1100 	 Step : 954000 	 Average Reward : 31.9832
# Episode : 1102 	 Step : 956000 	 Average Reward : 122.8236
# Episode : 1105 	 Step : 958000 	 Average Reward : -6.8582
# Episode : 1107 	 Step : 960000 	 Average Reward : 99.1301
# Episode : 1109 	 Step : 962000 	 Average Reward : 126.5892
# Episode : 1112 	 Step : 964000 	 Average Reward : 59.3872
# Episode : 1114 	 Step : 966000 	 Average Reward : 112.0836
# Episode : 1116 	 Step : 968000 	 Average Reward : 108.0189
# Episode : 1118 	 Step : 970000 	 Average Reward : 119.0098
# Episode : 1120 	 Step : 972000 	 Average Reward : 113.5439
# Episode : 1122 	 Step : 974000 	 Average Reward : 115.4073
# Episode : 1124 	 Step : 976000 	 Average Reward : 126.5951
# Episode : 1126 	 Step : 978000 	 Average Reward : 116.8538
# Episode : 1128 	 Step : 980000 	 Average Reward : 127.6298
# Episode : 1130 	 Step : 982000 	 Average Reward : 101.1444
# Episode : 1132 	 Step : 984000 	 Average Reward : 138.2598
# Episode : 1134 	 Step : 986000 	 Average Reward : 125.2165
# Episode : 1136 	 Step : 988000 	 Average Reward : 22.268
# Episode : 1138 	 Step : 990000 	 Average Reward : 132.8865
# Episode : 1140 	 Step : 992000 	 Average Reward : 129.9461
# Episode : 1142 	 Step : 994000 	 Average Reward : 119.4614
# Episode : 1144 	 Step : 996000 	 Average Reward : 123.0034
# Episode : 1146 	 Step : 998000 	 Average Reward : 124.8041
# Episode : 1148 	 Step : 1000000 	 Average Reward : 133.123
# Model Saved!!
# Episode : 1151 	 Step : 1002000 	 Average Reward : 51.4001
# Episode : 1153 	 Step : 1004000 	 Average Reward : 126.3908
# Episode : 1155 	 Step : 1006000 	 Average Reward : 134.9885
# Episode : 1157 	 Step : 1008000 	 Average Reward : 145.9262
# Episode : 1160 	 Step : 1010000 	 Average Reward : 53.9264
# Episode : 1162 	 Step : 1012000 	 Average Reward : 137.4062
# Episode : 1164 	 Step : 1014000 	 Average Reward : 135.3829
# Episode : 1166 	 Step : 1016000 	 Average Reward : 143.1698
# Episode : 1168 	 Step : 1018000 	 Average Reward : 141.5908
# Episode : 1170 	 Step : 1020000 	 Average Reward : 140.0548
# Episode : 1172 	 Step : 1022000 	 Average Reward : 147.1865
# Episode : 1174 	 Step : 1024000 	 Average Reward : 134.5803
# Episode : 1176 	 Step : 1026000 	 Average Reward : 138.3479
# Episode : 1178 	 Step : 1028000 	 Average Reward : 127.2856
# Episode : 1180 	 Step : 1030000 	 Average Reward : 151.5427
# Episode : 1182 	 Step : 1032000 	 Average Reward : 134.635
# Episode : 1184 	 Step : 1034000 	 Average Reward : 143.5404
# Episode : 1186 	 Step : 1036000 	 Average Reward : 138.7021
# Episode : 1188 	 Step : 1038000 	 Average Reward : 144.0444
# Episode : 1190 	 Step : 1040000 	 Average Reward : 136.2288
# Episode : 1192 	 Step : 1042000 	 Average Reward : 139.1021
# Episode : 1194 	 Step : 1044000 	 Average Reward : 157.1056
# Episode : 1196 	 Step : 1046000 	 Average Reward : 150.8109
# Episode : 1198 	 Step : 1048000 	 Average Reward : 148.9501
# Episode : 1201 	 Step : 1050000 	 Average Reward : 48.3349
# Episode : 1203 	 Step : 1052000 	 Average Reward : 133.5149
# Episode : 1205 	 Step : 1054000 	 Average Reward : 153.8015
# Episode : 1207 	 Step : 1056000 	 Average Reward : 148.2817
# Episode : 1209 	 Step : 1058000 	 Average Reward : 78.4363
# Episode : 1212 	 Step : 1060000 	 Average Reward : 89.5292
# Episode : 1214 	 Step : 1062000 	 Average Reward : 138.4997
# Episode : 1216 	 Step : 1064000 	 Average Reward : 140.7183
# Episode : 1218 	 Step : 1066000 	 Average Reward : 136.5876
# Episode : 1220 	 Step : 1068000 	 Average Reward : 48.6871
# Episode : 1222 	 Step : 1070000 	 Average Reward : 152.2511
# Episode : 1224 	 Step : 1072000 	 Average Reward : 154.6799
# Episode : 1226 	 Step : 1074000 	 Average Reward : 143.2578
# Episode : 1228 	 Step : 1076000 	 Average Reward : 56.9443
# Episode : 1230 	 Step : 1078000 	 Average Reward : 147.6148
# Episode : 1232 	 Step : 1080000 	 Average Reward : 143.3973
# Episode : 1234 	 Step : 1082000 	 Average Reward : 147.6482
# Episode : 1237 	 Step : 1084000 	 Average Reward : 75.5003
# Episode : 1239 	 Step : 1086000 	 Average Reward : 142.1971
# Episode : 1241 	 Step : 1088000 	 Average Reward : 154.6277
# Episode : 1243 	 Step : 1090000 	 Average Reward : 162.6473
# Episode : 1245 	 Step : 1092000 	 Average Reward : 145.4138
# Episode : 1247 	 Step : 1094000 	 Average Reward : 155.3315
# Episode : 1249 	 Step : 1096000 	 Average Reward : 126.8418
# Episode : 1251 	 Step : 1098000 	 Average Reward : 40.723
# Episode : 1253 	 Step : 1100000 	 Average Reward : 151.2318
# Episode : 1255 	 Step : 1102000 	 Average Reward : 144.6885
# Episode : 1257 	 Step : 1104000 	 Average Reward : 145.6445
# Episode : 1259 	 Step : 1106000 	 Average Reward : 147.3179
# Episode : 1261 	 Step : 1108000 	 Average Reward : 152.1641
# Episode : 1263 	 Step : 1110000 	 Average Reward : 152.8631
# Episode : 1266 	 Step : 1112000 	 Average Reward : 85.9886
# Episode : 1268 	 Step : 1114000 	 Average Reward : 156.8228
# Episode : 1270 	 Step : 1116000 	 Average Reward : 163.0852
# Episode : 1272 	 Step : 1118000 	 Average Reward : 156.2466
# Episode : 1274 	 Step : 1120000 	 Average Reward : 156.3253
# Episode : 1276 	 Step : 1122000 	 Average Reward : 153.664
# Episode : 1279 	 Step : 1124000 	 Average Reward : 67.0758
# Episode : 1281 	 Step : 1126000 	 Average Reward : 20.7256
# Episode : 1283 	 Step : 1128000 	 Average Reward : 150.66
# Episode : 1285 	 Step : 1130000 	 Average Reward : 155.8638
# Episode : 1287 	 Step : 1132000 	 Average Reward : 154.9536
# Episode : 1289 	 Step : 1134000 	 Average Reward : 104.4012
# Episode : 1291 	 Step : 1136000 	 Average Reward : 92.0522
# Episode : 1293 	 Step : 1138000 	 Average Reward : 153.9604
# Episode : 1296 	 Step : 1140000 	 Average Reward : 104.1888
# Episode : 1298 	 Step : 1142000 	 Average Reward : 155.0204
# Episode : 1301 	 Step : 1144000 	 Average Reward : 29.0821
# Episode : 1303 	 Step : 1146000 	 Average Reward : 35.5158
# Episode : 1306 	 Step : 1148000 	 Average Reward : 89.9201
# Episode : 1308 	 Step : 1150000 	 Average Reward : 162.6631
# Episode : 1310 	 Step : 1152000 	 Average Reward : 170.2648
# Episode : 1313 	 Step : 1154000 	 Average Reward : 76.7021
# Episode : 1315 	 Step : 1156000 	 Average Reward : 160.4011
# Episode : 1317 	 Step : 1158000 	 Average Reward : 162.3197
# Episode : 1319 	 Step : 1160000 	 Average Reward : 162.6669
# Episode : 1321 	 Step : 1162000 	 Average Reward : 144.8069
# Episode : 1324 	 Step : 1164000 	 Average Reward : 76.6205
# Episode : 1326 	 Step : 1166000 	 Average Reward : 161.0797
# Episode : 1328 	 Step : 1168000 	 Average Reward : 98.3245
# Episode : 1330 	 Step : 1170000 	 Average Reward : 84.9177
# Episode : 1332 	 Step : 1172000 	 Average Reward : 136.0772
# Episode : 1335 	 Step : 1174000 	 Average Reward : 70.5762
# Episode : 1337 	 Step : 1176000 	 Average Reward : 161.1883
# Episode : 1339 	 Step : 1178000 	 Average Reward : 163.3318
# Episode : 1342 	 Step : 1180000 	 Average Reward : 21.9178
# Episode : 1344 	 Step : 1182000 	 Average Reward : 149.2198
# Episode : 1346 	 Step : 1184000 	 Average Reward : 144.0845
# Episode : 1348 	 Step : 1186000 	 Average Reward : 171.4046
# Episode : 1350 	 Step : 1188000 	 Average Reward : 166.9547
# Episode : 1352 	 Step : 1190000 	 Average Reward : 164.9979
# Episode : 1354 	 Step : 1192000 	 Average Reward : 155.7695
# Episode : 1356 	 Step : 1194000 	 Average Reward : 163.5264
# Episode : 1358 	 Step : 1196000 	 Average Reward : 160.0294
# Episode : 1360 	 Step : 1198000 	 Average Reward : 154.2454
# Episode : 1362 	 Step : 1200000 	 Average Reward : 93.7105
# Model Saved!!
# Episode : 1365 	 Step : 1202000 	 Average Reward : 99.9278
# Episode : 1367 	 Step : 1204000 	 Average Reward : 163.2456
# Episode : 1369 	 Step : 1206000 	 Average Reward : 162.9724
# Episode : 1371 	 Step : 1208000 	 Average Reward : 78.4138
# Episode : 1374 	 Step : 1210000 	 Average Reward : 87.6508
# Episode : 1376 	 Step : 1212000 	 Average Reward : 167.0112
# Episode : 1378 	 Step : 1214000 	 Average Reward : 172.0534
# Episode : 1380 	 Step : 1216000 	 Average Reward : 173.8747
# Episode : 1382 	 Step : 1218000 	 Average Reward : 88.5623
# Episode : 1384 	 Step : 1220000 	 Average Reward : 165.3056
# Episode : 1386 	 Step : 1222000 	 Average Reward : 163.9105
# Episode : 1388 	 Step : 1224000 	 Average Reward : 160.7376
# Episode : 1390 	 Step : 1226000 	 Average Reward : 86.1016
# Episode : 1392 	 Step : 1228000 	 Average Reward : 171.0682
# Episode : 1394 	 Step : 1230000 	 Average Reward : 165.3501
# Episode : 1396 	 Step : 1232000 	 Average Reward : 175.0171
# Episode : 1399 	 Step : 1234000 	 Average Reward : 80.4264
# Episode : 1401 	 Step : 1236000 	 Average Reward : 175.0995
# Episode : 1403 	 Step : 1238000 	 Average Reward : 154.4016
# Episode : 1406 	 Step : 1240000 	 Average Reward : 85.9311
# Episode : 1408 	 Step : 1242000 	 Average Reward : 155.9549
# Episode : 1410 	 Step : 1244000 	 Average Reward : 163.7099
# Episode : 1412 	 Step : 1246000 	 Average Reward : 167.1496
# Episode : 1414 	 Step : 1248000 	 Average Reward : 164.2656
# Episode : 1416 	 Step : 1250000 	 Average Reward : 167.1951
# Episode : 1418 	 Step : 1252000 	 Average Reward : 176.2296
# Episode : 1420 	 Step : 1254000 	 Average Reward : 182.3882
# Episode : 1422 	 Step : 1256000 	 Average Reward : 108.0126
# Episode : 1424 	 Step : 1258000 	 Average Reward : 178.8422
# Episode : 1427 	 Step : 1260000 	 Average Reward : 122.5363
# Episode : 1429 	 Step : 1262000 	 Average Reward : 54.6991
# Episode : 1431 	 Step : 1264000 	 Average Reward : 183.6426
# Episode : 1433 	 Step : 1266000 	 Average Reward : 187.0715
# Episode : 1435 	 Step : 1268000 	 Average Reward : 182.4452
# Episode : 1437 	 Step : 1270000 	 Average Reward : 127.1554
# Episode : 1439 	 Step : 1272000 	 Average Reward : 179.2518
# Episode : 1441 	 Step : 1274000 	 Average Reward : 186.5668
# Episode : 1443 	 Step : 1276000 	 Average Reward : 158.4993
# Episode : 1446 	 Step : 1278000 	 Average Reward : 114.6616
# Episode : 1448 	 Step : 1280000 	 Average Reward : 170.9597
# Episode : 1450 	 Step : 1282000 	 Average Reward : 90.6483
# Episode : 1452 	 Step : 1284000 	 Average Reward : 183.8567
# Episode : 1454 	 Step : 1286000 	 Average Reward : 178.5296
# Episode : 1456 	 Step : 1288000 	 Average Reward : 92.7723
# Episode : 1458 	 Step : 1290000 	 Average Reward : 172.1346
# Episode : 1460 	 Step : 1292000 	 Average Reward : 182.2223
# Episode : 1462 	 Step : 1294000 	 Average Reward : 182.6802
# Episode : 1465 	 Step : 1296000 	 Average Reward : 30.7488
# Episode : 1468 	 Step : 1298000 	 Average Reward : 105.7151
# Episode : 1470 	 Step : 1300000 	 Average Reward : -10.8923
# Episode : 1472 	 Step : 1302000 	 Average Reward : 178.4523
# Episode : 1474 	 Step : 1304000 	 Average Reward : 176.548
# Episode : 1476 	 Step : 1306000 	 Average Reward : 158.2232
# Episode : 1478 	 Step : 1308000 	 Average Reward : 171.8223
# Episode : 1480 	 Step : 1310000 	 Average Reward : 172.767
# Episode : 1482 	 Step : 1312000 	 Average Reward : 182.5367
# Episode : 1485 	 Step : 1314000 	 Average Reward : 76.7934
# Episode : 1487 	 Step : 1316000 	 Average Reward : 173.8181
# Episode : 1489 	 Step : 1318000 	 Average Reward : 181.6974
# Episode : 1492 	 Step : 1320000 	 Average Reward : 77.23
# Episode : 1494 	 Step : 1322000 	 Average Reward : 179.3369
# Episode : 1496 	 Step : 1324000 	 Average Reward : 180.6297
# Episode : 1498 	 Step : 1326000 	 Average Reward : 180.7843
# Episode : 1500 	 Step : 1328000 	 Average Reward : 170.3153
# Episode : 1502 	 Step : 1330000 	 Average Reward : 181.9068
# Episode : 1504 	 Step : 1332000 	 Average Reward : 176.9337
# Episode : 1506 	 Step : 1334000 	 Average Reward : 166.657
# Episode : 1509 	 Step : 1336000 	 Average Reward : 96.7402
# Episode : 1511 	 Step : 1338000 	 Average Reward : 174.0157
# Episode : 1513 	 Step : 1340000 	 Average Reward : 181.2748
# Episode : 1515 	 Step : 1342000 	 Average Reward : 104.698
# Episode : 1517 	 Step : 1344000 	 Average Reward : 161.3284
# Episode : 1519 	 Step : 1346000 	 Average Reward : 147.1456
# Episode : 1521 	 Step : 1348000 	 Average Reward : 179.2224
# Episode : 1523 	 Step : 1350000 	 Average Reward : 96.4338
# Episode : 1526 	 Step : 1352000 	 Average Reward : 61.5436
# Episode : 1528 	 Step : 1354000 	 Average Reward : 156.3066
# Episode : 1530 	 Step : 1356000 	 Average Reward : 160.5983
# Episode : 1532 	 Step : 1358000 	 Average Reward : 183.8377
# Episode : 1534 	 Step : 1360000 	 Average Reward : 112.0264
# Episode : 1536 	 Step : 1362000 	 Average Reward : 172.0064
# Episode : 1538 	 Step : 1364000 	 Average Reward : 171.4385
# Episode : 1540 	 Step : 1366000 	 Average Reward : 169.5078
# Episode : 1543 	 Step : 1368000 	 Average Reward : 94.9614
# Episode : 1545 	 Step : 1370000 	 Average Reward : 188.3714
# Episode : 1547 	 Step : 1372000 	 Average Reward : 186.4077
# Episode : 1549 	 Step : 1374000 	 Average Reward : 57.187
# Episode : 1552 	 Step : 1376000 	 Average Reward : 119.6547
# Episode : 1554 	 Step : 1378000 	 Average Reward : 171.0862
# Episode : 1556 	 Step : 1380000 	 Average Reward : 90.9759
# Episode : 1558 	 Step : 1382000 	 Average Reward : 95.9775
# Episode : 1560 	 Step : 1384000 	 Average Reward : 176.0528
# Episode : 1562 	 Step : 1386000 	 Average Reward : 175.451
# Episode : 1564 	 Step : 1388000 	 Average Reward : 173.3592
# Episode : 1566 	 Step : 1390000 	 Average Reward : 179.0026
# Episode : 1568 	 Step : 1392000 	 Average Reward : 190.1621
# Episode : 1570 	 Step : 1394000 	 Average Reward : 180.1487
# Episode : 1572 	 Step : 1396000 	 Average Reward : 175.684
# Episode : 1574 	 Step : 1398000 	 Average Reward : 179.4226
# Episode : 1577 	 Step : 1400000 	 Average Reward : 93.2086
# Model Saved!!
# Episode : 1579 	 Step : 1402000 	 Average Reward : 93.9346
# Episode : 1581 	 Step : 1404000 	 Average Reward : 180.1465
# Episode : 1583 	 Step : 1406000 	 Average Reward : 170.3846
# Episode : 1586 	 Step : 1408000 	 Average Reward : 89.575
# Episode : 1589 	 Step : 1410000 	 Average Reward : 107.7093
# Episode : 1591 	 Step : 1412000 	 Average Reward : 185.7532
# Episode : 1593 	 Step : 1414000 	 Average Reward : 200.0065
# Episode : 1595 	 Step : 1416000 	 Average Reward : 172.5984
# Episode : 1597 	 Step : 1418000 	 Average Reward : 122.3561
# Episode : 1599 	 Step : 1420000 	 Average Reward : 187.7614
# Episode : 1601 	 Step : 1422000 	 Average Reward : 59.1994
# Episode : 1603 	 Step : 1424000 	 Average Reward : 185.6844
# Episode : 1606 	 Step : 1426000 	 Average Reward : 98.9058
# Episode : 1608 	 Step : 1428000 	 Average Reward : 190.4534
# Episode : 1610 	 Step : 1430000 	 Average Reward : 175.843
# Episode : 1612 	 Step : 1432000 	 Average Reward : 132.1071
# Episode : 1614 	 Step : 1434000 	 Average Reward : 192.0449
# Episode : 1616 	 Step : 1436000 	 Average Reward : 188.0508
# Episode : 1618 	 Step : 1438000 	 Average Reward : 189.8008
# Episode : 1620 	 Step : 1440000 	 Average Reward : 162.3204
# Episode : 1623 	 Step : 1442000 	 Average Reward : 138.1554
# Episode : 1625 	 Step : 1444000 	 Average Reward : 40.4712
# Episode : 1627 	 Step : 1446000 	 Average Reward : 132.4643
# Episode : 1630 	 Step : 1448000 	 Average Reward : 117.1436
# Episode : 1633 	 Step : 1450000 	 Average Reward : 71.2123
# Episode : 1635 	 Step : 1452000 	 Average Reward : 133.0803
# Episode : 1637 	 Step : 1454000 	 Average Reward : 191.5159
# Episode : 1639 	 Step : 1456000 	 Average Reward : 191.4606
# Episode : 1641 	 Step : 1458000 	 Average Reward : 180.5289
# Episode : 1643 	 Step : 1460000 	 Average Reward : 194.7439
# Episode : 1645 	 Step : 1462000 	 Average Reward : 71.1603
# Episode : 1647 	 Step : 1464000 	 Average Reward : 196.939
# Episode : 1650 	 Step : 1466000 	 Average Reward : 115.735
# Episode : 1652 	 Step : 1468000 	 Average Reward : 181.4732
# Episode : 1654 	 Step : 1470000 	 Average Reward : 187.393
# Episode : 1656 	 Step : 1472000 	 Average Reward : 193.8709
# Episode : 1658 	 Step : 1474000 	 Average Reward : 125.3335
# Episode : 1660 	 Step : 1476000 	 Average Reward : 189.1265
# Episode : 1663 	 Step : 1478000 	 Average Reward : 101.8603
# Episode : 1665 	 Step : 1480000 	 Average Reward : 75.3084
# Episode : 1668 	 Step : 1482000 	 Average Reward : 84.9348
# Episode : 1671 	 Step : 1484000 	 Average Reward : 109.7432
# Episode : 1673 	 Step : 1486000 	 Average Reward : 187.9506
# Episode : 1675 	 Step : 1488000 	 Average Reward : 192.4731
# Episode : 1677 	 Step : 1490000 	 Average Reward : 190.9851
# Episode : 1679 	 Step : 1492000 	 Average Reward : 198.6183
# Episode : 1682 	 Step : 1494000 	 Average Reward : 119.2267
# Episode : 1684 	 Step : 1496000 	 Average Reward : 189.8368
# Episode : 1686 	 Step : 1498000 	 Average Reward : 192.9391
# Episode : 1688 	 Step : 1500000 	 Average Reward : 129.298
# Episode : 1690 	 Step : 1502000 	 Average Reward : 85.2902
# Episode : 1694 	 Step : 1504000 	 Average Reward : 37.0879
# Episode : 1696 	 Step : 1506000 	 Average Reward : 189.2228
# Episode : 1698 	 Step : 1508000 	 Average Reward : 206.2535
# Episode : 1700 	 Step : 1510000 	 Average Reward : 201.2126
# Episode : 1702 	 Step : 1512000 	 Average Reward : 197.0009
# Episode : 1704 	 Step : 1514000 	 Average Reward : 204.7646
# Episode : 1706 	 Step : 1516000 	 Average Reward : 195.7217
# Episode : 1708 	 Step : 1518000 	 Average Reward : 139.2869
# Episode : 1710 	 Step : 1520000 	 Average Reward : 189.5203
# Episode : 1712 	 Step : 1522000 	 Average Reward : 181.6895
# Episode : 1714 	 Step : 1524000 	 Average Reward : 13.0767
# Episode : 1716 	 Step : 1526000 	 Average Reward : 197.3186
# Episode : 1718 	 Step : 1528000 	 Average Reward : 199.5094
# Episode : 1721 	 Step : 1530000 	 Average Reward : 147.905
# Episode : 1723 	 Step : 1532000 	 Average Reward : 97.8361
# Episode : 1725 	 Step : 1534000 	 Average Reward : 210.4066
# Episode : 1728 	 Step : 1536000 	 Average Reward : 69.3902
# Episode : 1730 	 Step : 1538000 	 Average Reward : 207.5122
# Episode : 1732 	 Step : 1540000 	 Average Reward : 205.0583
# Episode : 1734 	 Step : 1542000 	 Average Reward : 201.3669
# Episode : 1736 	 Step : 1544000 	 Average Reward : 206.8387
# Episode : 1739 	 Step : 1546000 	 Average Reward : 113.5676
# Episode : 1741 	 Step : 1548000 	 Average Reward : 191.0351
# Episode : 1744 	 Step : 1550000 	 Average Reward : 19.3249
# Episode : 1746 	 Step : 1552000 	 Average Reward : 207.4283
# Episode : 1749 	 Step : 1554000 	 Average Reward : 115.005
# Episode : 1751 	 Step : 1556000 	 Average Reward : 193.9458
# Episode : 1753 	 Step : 1558000 	 Average Reward : 116.4128
# Episode : 1755 	 Step : 1560000 	 Average Reward : 210.1713
# Episode : 1759 	 Step : 1562000 	 Average Reward : 11.9403
# Episode : 1761 	 Step : 1564000 	 Average Reward : 97.2983
# Episode : 1763 	 Step : 1566000 	 Average Reward : 216.8311
# Episode : 1765 	 Step : 1568000 	 Average Reward : 218.664
# Episode : 1769 	 Step : 1570000 	 Average Reward : 56.4039
# Episode : 1771 	 Step : 1572000 	 Average Reward : 98.4388
# Episode : 1773 	 Step : 1574000 	 Average Reward : 209.5456
# Episode : 1776 	 Step : 1576000 	 Average Reward : 51.3147
# Episode : 1780 	 Step : 1578000 	 Average Reward : 82.1761
# Episode : 1783 	 Step : 1580000 	 Average Reward : 99.7028
# Episode : 1786 	 Step : 1582000 	 Average Reward : 45.1618
# Episode : 1788 	 Step : 1584000 	 Average Reward : 77.1865
# Episode : 1790 	 Step : 1586000 	 Average Reward : 209.7595
# Episode : 1793 	 Step : 1588000 	 Average Reward : 120.3853
# Episode : 1795 	 Step : 1590000 	 Average Reward : 198.5466
# Episode : 1797 	 Step : 1592000 	 Average Reward : 207.9543
# Episode : 1799 	 Step : 1594000 	 Average Reward : 206.175
# Episode : 1801 	 Step : 1596000 	 Average Reward : 123.7608
# Episode : 1803 	 Step : 1598000 	 Average Reward : 212.9987
# Episode : 1806 	 Step : 1600000 	 Average Reward : 125.9764
# Model Saved!!
# Episode : 1808 	 Step : 1602000 	 Average Reward : 204.7846
# Episode : 1810 	 Step : 1604000 	 Average Reward : 202.1419
# Episode : 1813 	 Step : 1606000 	 Average Reward : 110.6722
# Episode : 1815 	 Step : 1608000 	 Average Reward : 83.7674
# Episode : 1817 	 Step : 1610000 	 Average Reward : 213.6752
# Episode : 1819 	 Step : 1612000 	 Average Reward : 173.1077
# Episode : 1823 	 Step : 1614000 	 Average Reward : 74.4576
# Episode : 1825 	 Step : 1616000 	 Average Reward : 46.4647
# Episode : 1828 	 Step : 1618000 	 Average Reward : 133.2411
# Episode : 1830 	 Step : 1620000 	 Average Reward : 202.0151
# Episode : 1832 	 Step : 1622000 	 Average Reward : 210.8193
# Episode : 1835 	 Step : 1624000 	 Average Reward : 90.7326
# Episode : 1837 	 Step : 1626000 	 Average Reward : 147.6858
# Episode : 1839 	 Step : 1628000 	 Average Reward : 138.2503
# Episode : 1842 	 Step : 1630000 	 Average Reward : 100.7369
# Episode : 1844 	 Step : 1632000 	 Average Reward : 114.8327
# Episode : 1846 	 Step : 1634000 	 Average Reward : 206.6367
# Episode : 1848 	 Step : 1636000 	 Average Reward : 192.1026
# Episode : 1850 	 Step : 1638000 	 Average Reward : 205.949
# Episode : 1852 	 Step : 1640000 	 Average Reward : 215.8504
# Episode : 1855 	 Step : 1642000 	 Average Reward : 111.877
# Episode : 1857 	 Step : 1644000 	 Average Reward : 199.9069
# ...
# Episode : 3801 	 Step : 3470000 	 Average Reward : 280.0554
# Episode : 3803 	 Step : 3472000 	 Average Reward : 260.5597
# Episode : 3805 	 Step : 3474000 	 Average Reward : 272.0043
# Episode : 3807 	 Step : 3476000 	 Average Reward : 268.5696
# Episode : 3809 	 Step : 3478000 	 Average Reward : 271.1171
# Episode : 3811 	 Step : 3480000 	 Average Reward : 272.4831
# Episode : 3813 	 Step : 3482000 	 Average Reward : 272.8397
# Episode : 3815 	 Step : 3484000 	 Average Reward : 257.3063
# Episode : 3818 	 Step : 3486000 	 Average Reward : 173.0996
# Episode : 3820 	 Step : 3488000 	 Average Reward : 267.336
# Episode : 3822 	 Step : 3490000 	 Average Reward : 280.0885
# Episode : 3824 	 Step : 3492000 	 Average Reward : 274.8382
# Episode : 3826 	 Step : 3494000 	 Average Reward : 275.7233
# Episode : 3828 	 Step : 3496000 	 Average Reward : 166.7394
# Episode : 3830 	 Step : 3498000 	 Average Reward : 280.2505
# Episode : 3832 	 Step : 3500000 	 Average Reward : 154.8931
# Episode : 3834 	 Step : 3502000 	 Average Reward : 271.7295
# Episode : 3836 	 Step : 3504000 	 Average Reward : 256.5263
# Episode : 3838 	 Step : 3506000 	 Average Reward : 266.6933
# Episode : 3840 	 Step : 3508000 	 Average Reward : 269.545
# Episode : 3842 	 Step : 3510000 	 Average Reward : 277.7568
# Episode : 3844 	 Step : 3512000 	 Average Reward : 268.7322
# Episode : 3846 	 Step : 3514000 	 Average Reward : 277.3071
# Episode : 3848 	 Step : 3516000 	 Average Reward : 265.4526
# Episode : 3850 	 Step : 3518000 	 Average Reward : 281.1239
# Episode : 3852 	 Step : 3520000 	 Average Reward : 271.8183
# Episode : 3854 	 Step : 3522000 	 Average Reward : 283.4065
# Episode : 3856 	 Step : 3524000 	 Average Reward : 271.7559
# Episode : 3858 	 Step : 3526000 	 Average Reward : 277.4695
# Episode : 3860 	 Step : 3528000 	 Average Reward : 274.6114
# Episode : 3863 	 Step : 3530000 	 Average Reward : 127.8197
# Episode : 3866 	 Step : 3532000 	 Average Reward : 197.2565
# Episode : 3868 	 Step : 3534000 	 Average Reward : 283.3689
# Episode : 3870 	 Step : 3536000 	 Average Reward : 136.9816
# Episode : 3872 	 Step : 3538000 	 Average Reward : 277.8119
# Episode : 3874 	 Step : 3540000 	 Average Reward : 270.412
# Episode : 3877 	 Step : 3542000 	 Average Reward : 182.6619
# Episode : 3879 	 Step : 3544000 	 Average Reward : 272.9029
# Episode : 3881 	 Step : 3546000 	 Average Reward : 260.4426
# Episode : 3883 	 Step : 3548000 	 Average Reward : 257.2641
# Episode : 3885 	 Step : 3550000 	 Average Reward : 272.3412
# Episode : 3887 	 Step : 3552000 	 Average Reward : 178.6435
# Episode : 3889 	 Step : 3554000 	 Average Reward : 277.3226
# Episode : 3891 	 Step : 3556000 	 Average Reward : 267.7277
# Episode : 3894 	 Step : 3558000 	 Average Reward : 169.9592
# Episode : 3896 	 Step : 3560000 	 Average Reward : 274.2317
# Episode : 3898 	 Step : 3562000 	 Average Reward : 255.2056
# Episode : 3900 	 Step : 3564000 	 Average Reward : 261.297
# Episode : 3902 	 Step : 3566000 	 Average Reward : 270.5037
# Episode : 3904 	 Step : 3568000 	 Average Reward : 264.1294
# Episode : 3906 	 Step : 3570000 	 Average Reward : 271.936
# Episode : 3908 	 Step : 3572000 	 Average Reward : 264.4963
# Episode : 3910 	 Step : 3574000 	 Average Reward : 145.5771
# Episode : 3912 	 Step : 3576000 	 Average Reward : 277.305
# Episode : 3914 	 Step : 3578000 	 Average Reward : 216.8371
# Episode : 3916 	 Step : 3580000 	 Average Reward : 276.8886
# Episode : 3919 	 Step : 3582000 	 Average Reward : 175.9798
# Episode : 3921 	 Step : 3584000 	 Average Reward : 250.7385
# Episode : 3923 	 Step : 3586000 	 Average Reward : 162.9284
# Episode : 3925 	 Step : 3588000 	 Average Reward : 273.5954
# Episode : 3927 	 Step : 3590000 	 Average Reward : 282.1557
# Episode : 3929 	 Step : 3592000 	 Average Reward : 277.2977
# Episode : 3931 	 Step : 3594000 	 Average Reward : 271.9977
# Episode : 3933 	 Step : 3596000 	 Average Reward : 267.7072
# Episode : 3935 	 Step : 3598000 	 Average Reward : 271.9715
# Episode : 3938 	 Step : 3600000 	 Average Reward : 171.4131
# Model Saved!!
# Episode : 3940 	 Step : 3602000 	 Average Reward : 272.6926
# Episode : 3942 	 Step : 3604000 	 Average Reward : 273.8397
# Episode : 3944 	 Step : 3606000 	 Average Reward : 257.2907
# Episode : 3946 	 Step : 3608000 	 Average Reward : 273.3229
# Episode : 3949 	 Step : 3610000 	 Average Reward : 87.8845
# Episode : 3951 	 Step : 3612000 	 Average Reward : 266.1927
# Episode : 3953 	 Step : 3614000 	 Average Reward : 272.1122
# Episode : 3955 	 Step : 3616000 	 Average Reward : 267.5219
# Episode : 3957 	 Step : 3618000 	 Average Reward : 174.9576
# Episode : 3960 	 Step : 3620000 	 Average Reward : 169.3316
# Episode : 3962 	 Step : 3622000 	 Average Reward : 264.3628
# Episode : 3964 	 Step : 3624000 	 Average Reward : 276.374
# Episode : 3966 	 Step : 3626000 	 Average Reward : 270.1585
# Episode : 3968 	 Step : 3628000 	 Average Reward : 131.117
# Episode : 3970 	 Step : 3630000 	 Average Reward : 276.2769
# Episode : 3972 	 Step : 3632000 	 Average Reward : 278.1479
# Episode : 3974 	 Step : 3634000 	 Average Reward : 277.2362
# Episode : 3976 	 Step : 3636000 	 Average Reward : 179.7388
# Episode : 3978 	 Step : 3638000 	 Average Reward : 264.4408
# Episode : 3980 	 Step : 3640000 	 Average Reward : 265.4047
# Episode : 3982 	 Step : 3642000 	 Average Reward : 270.328
# Episode : 3984 	 Step : 3644000 	 Average Reward : 251.3485
# Episode : 3987 	 Step : 3646000 	 Average Reward : 161.2589
# Episode : 3989 	 Step : 3648000 	 Average Reward : 282.104
# Episode : 3991 	 Step : 3650000 	 Average Reward : 278.4171
# Episode : 3993 	 Step : 3652000 	 Average Reward : 273.884
# Episode : 3995 	 Step : 3654000 	 Average Reward : 261.7657
# Episode : 3997 	 Step : 3656000 	 Average Reward : 247.5918
# Episode : 4000 	 Step : 3658000 	 Average Reward : 173.3048
# Episode : 4002 	 Step : 3660000 	 Average Reward : 268.6855
# Episode : 4004 	 Step : 3662000 	 Average Reward : 270.459
# Episode : 4006 	 Step : 3664000 	 Average Reward : 277.2152
# Episode : 4008 	 Step : 3666000 	 Average Reward : 115.1737
# Episode : 4011 	 Step : 3668000 	 Average Reward : 199.1301
# Episode : 4013 	 Step : 3670000 	 Average Reward : 269.1048
# Episode : 4015 	 Step : 3672000 	 Average Reward : 114.6133
# Episode : 4017 	 Step : 3674000 	 Average Reward : 275.6072
# Episode : 4019 	 Step : 3676000 	 Average Reward : 278.3557
# Episode : 4021 	 Step : 3678000 	 Average Reward : 273.9472
# Episode : 4023 	 Step : 3680000 	 Average Reward : 284.8201
# Episode : 4025 	 Step : 3682000 	 Average Reward : 264.3781
# Episode : 4027 	 Step : 3684000 	 Average Reward : 287.901
# Episode : 4030 	 Step : 3686000 	 Average Reward : 149.8224
# Episode : 4032 	 Step : 3688000 	 Average Reward : 267.2444
# Episode : 4035 	 Step : 3690000 	 Average Reward : 164.5669
# Episode : 4037 	 Step : 3692000 	 Average Reward : 183.7357
# Episode : 4039 	 Step : 3694000 	 Average Reward : 271.9974
# Episode : 4041 	 Step : 3696000 	 Average Reward : 255.138
# Episode : 4043 	 Step : 3698000 	 Average Reward : 287.6238
# Episode : 4045 	 Step : 3700000 	 Average Reward : 258.6641
# Episode : 4047 	 Step : 3702000 	 Average Reward : 272.2613
# Episode : 4049 	 Step : 3704000 	 Average Reward : 163.8986
# Episode : 4051 	 Step : 3706000 	 Average Reward : 286.4285
# Episode : 4053 	 Step : 3708000 	 Average Reward : 265.6098
# Episode : 4056 	 Step : 3710000 	 Average Reward : 217.892
# Episode : 4058 	 Step : 3712000 	 Average Reward : 271.6591
# Episode : 4060 	 Step : 3714000 	 Average Reward : 269.9156
# Episode : 4062 	 Step : 3716000 	 Average Reward : 126.084
# Episode : 4064 	 Step : 3718000 	 Average Reward : 278.7031
# Episode : 4066 	 Step : 3720000 	 Average Reward : 280.1929
# Episode : 4068 	 Step : 3722000 	 Average Reward : 266.3571
# Episode : 4071 	 Step : 3724000 	 Average Reward : 151.0583
# Episode : 4073 	 Step : 3726000 	 Average Reward : 278.1332
# Episode : 4076 	 Step : 3728000 	 Average Reward : 204.4533
# Episode : 4078 	 Step : 3730000 	 Average Reward : 269.0375
# Episode : 4080 	 Step : 3732000 	 Average Reward : 274.3114
# Episode : 4082 	 Step : 3734000 	 Average Reward : 136.1247
# Episode : 4084 	 Step : 3736000 	 Average Reward : 281.4921
# Episode : 4086 	 Step : 3738000 	 Average Reward : 281.3049
# Episode : 4088 	 Step : 3740000 	 Average Reward : 273.0926
# Episode : 4090 	 Step : 3742000 	 Average Reward : 278.3763
# Episode : 4092 	 Step : 3744000 	 Average Reward : 293.7415
# Episode : 4094 	 Step : 3746000 	 Average Reward : 105.0269
# Episode : 4099 	 Step : 3748000 	 Average Reward : 65.1514
# Episode : 4101 	 Step : 3750000 	 Average Reward : 278.7337
# Episode : 4104 	 Step : 3752000 	 Average Reward : 153.6477
# Episode : 4106 	 Step : 3754000 	 Average Reward : 276.0405
# Episode : 4108 	 Step : 3756000 	 Average Reward : 197.1557
# Episode : 4110 	 Step : 3758000 	 Average Reward : 270.8242
# Episode : 4112 	 Step : 3760000 	 Average Reward : 279.2372
# Episode : 4114 	 Step : 3762000 	 Average Reward : 274.9186
# Episode : 4117 	 Step : 3764000 	 Average Reward : 64.4945
# Episode : 4119 	 Step : 3766000 	 Average Reward : 190.0498
# Episode : 4121 	 Step : 3768000 	 Average Reward : 269.9977
# Episode : 4123 	 Step : 3770000 	 Average Reward : 284.7806
# Episode : 4125 	 Step : 3772000 	 Average Reward : 275.2759
# Episode : 4127 	 Step : 3774000 	 Average Reward : 277.3705
# Episode : 4130 	 Step : 3776000 	 Average Reward : 201.6138
# Episode : 4132 	 Step : 3778000 	 Average Reward : 267.5443
# Episode : 4134 	 Step : 3780000 	 Average Reward : 151.9614
# Episode : 4136 	 Step : 3782000 	 Average Reward : 272.7953
# Episode : 4140 	 Step : 3784000 	 Average Reward : 110.4941
# Episode : 4142 	 Step : 3786000 	 Average Reward : 265.4216
# Episode : 4144 	 Step : 3788000 	 Average Reward : 277.2601
# Episode : 4146 	 Step : 3790000 	 Average Reward : 111.5944
# Episode : 4149 	 Step : 3792000 	 Average Reward : 209.9785
# Episode : 4151 	 Step : 3794000 	 Average Reward : 278.4128
# Episode : 4153 	 Step : 3796000 	 Average Reward : 274.0019
# Episode : 4155 	 Step : 3798000 	 Average Reward : 266.1854
# Episode : 4157 	 Step : 3800000 	 Average Reward : 150.0847
# Model Saved!!
# Episode : 4159 	 Step : 3802000 	 Average Reward : 268.4623
# Episode : 4161 	 Step : 3804000 	 Average Reward : 279.8161
# Episode : 4163 	 Step : 3806000 	 Average Reward : 276.1653
# Episode : 4165 	 Step : 3808000 	 Average Reward : 281.6699
# Episode : 4167 	 Step : 3810000 	 Average Reward : 195.2947
# Episode : 4169 	 Step : 3812000 	 Average Reward : 276.4495
# Episode : 4172 	 Step : 3814000 	 Average Reward : 150.1157
# Episode : 4174 	 Step : 3816000 	 Average Reward : 273.17
# Episode : 4176 	 Step : 3818000 	 Average Reward : 263.4481
# Episode : 4178 	 Step : 3820000 	 Average Reward : 278.6544
# Episode : 4180 	 Step : 3822000 	 Average Reward : 266.1297
# Episode : 4182 	 Step : 3824000 	 Average Reward : 273.4195
# Episode : 4184 	 Step : 3826000 	 Average Reward : 275.3607
# Episode : 4186 	 Step : 3828000 	 Average Reward : 267.0472
# Episode : 4188 	 Step : 3830000 	 Average Reward : 269.6769
# Episode : 4190 	 Step : 3832000 	 Average Reward : 276.5956
# Episode : 4192 	 Step : 3834000 	 Average Reward : 266.87
# Episode : 4194 	 Step : 3836000 	 Average Reward : 285.1392
# Episode : 4196 	 Step : 3838000 	 Average Reward : 156.4615
# Episode : 4199 	 Step : 3840000 	 Average Reward : 209.2378
# Episode : 4202 	 Step : 3842000 	 Average Reward : 99.0758
# Episode : 4204 	 Step : 3844000 	 Average Reward : 279.2763
# Episode : 4207 	 Step : 3846000 	 Average Reward : 131.5066
# Episode : 4209 	 Step : 3848000 	 Average Reward : 123.6872
# Episode : 4211 	 Step : 3850000 	 Average Reward : 270.2154
# Episode : 4213 	 Step : 3852000 	 Average Reward : 263.6851
# Episode : 4215 	 Step : 3854000 	 Average Reward : 282.8611
# Episode : 4217 	 Step : 3856000 	 Average Reward : 282.8596
# Episode : 4220 	 Step : 3858000 	 Average Reward : 175.5195
# Episode : 4222 	 Step : 3860000 	 Average Reward : 276.7431
# Episode : 4224 	 Step : 3862000 	 Average Reward : 269.6202
# Episode : 4227 	 Step : 3864000 	 Average Reward : 27.1206
# Episode : 4229 	 Step : 3866000 	 Average Reward : 280.8133
# Episode : 4231 	 Step : 3868000 	 Average Reward : 150.8282
# Episode : 4233 	 Step : 3870000 	 Average Reward : 276.7551
# Episode : 4236 	 Step : 3872000 	 Average Reward : 179.3974
# Episode : 4238 	 Step : 3874000 	 Average Reward : 263.5029
# Episode : 4240 	 Step : 3876000 	 Average Reward : 278.1041
# Episode : 4242 	 Step : 3878000 	 Average Reward : 281.1484
# Episode : 4244 	 Step : 3880000 	 Average Reward : 213.0856
# Episode : 4246 	 Step : 3882000 	 Average Reward : 272.6316
# Episode : 4249 	 Step : 3884000 	 Average Reward : 159.1637
# Episode : 4251 	 Step : 3886000 	 Average Reward : 282.3632
# Episode : 4253 	 Step : 3888000 	 Average Reward : 45.3275
# Episode : 4258 	 Step : 3890000 	 Average Reward : 75.8424
# Episode : 4260 	 Step : 3892000 	 Average Reward : 284.75
# Episode : 4262 	 Step : 3894000 	 Average Reward : 172.3154
# Episode : 4264 	 Step : 3896000 	 Average Reward : 278.6534
# Episode : 4266 	 Step : 3898000 	 Average Reward : 278.3217
# Episode : 4268 	 Step : 3900000 	 Average Reward : 282.1591
# Episode : 4270 	 Step : 3902000 	 Average Reward : 161.3739
# Episode : 4272 	 Step : 3904000 	 Average Reward : 266.4091
# Episode : 4275 	 Step : 3906000 	 Average Reward : 164.1427
# Episode : 4277 	 Step : 3908000 	 Average Reward : 268.8894
# Episode : 4279 	 Step : 3910000 	 Average Reward : 267.5671
# Episode : 4282 	 Step : 3912000 	 Average Reward : 152.1112
# Episode : 4284 	 Step : 3914000 	 Average Reward : 270.0661
# Episode : 4286 	 Step : 3916000 	 Average Reward : 258.9426
# Episode : 4289 	 Step : 3918000 	 Average Reward : 175.5795
# Episode : 4291 	 Step : 3920000 	 Average Reward : 280.9315
# Episode : 4294 	 Step : 3922000 	 Average Reward : 79.1733
# Episode : 4296 	 Step : 3924000 	 Average Reward : 281.4013
# Episode : 4298 	 Step : 3926000 	 Average Reward : 274.6603
# Episode : 4301 	 Step : 3928000 	 Average Reward : 153.4321
# Episode : 4303 	 Step : 3930000 	 Average Reward : 271.146
# Episode : 4305 	 Step : 3932000 	 Average Reward : 278.0135
# Episode : 4307 	 Step : 3934000 	 Average Reward : 196.4887
# Episode : 4309 	 Step : 3936000 	 Average Reward : 280.9021
# Episode : 4311 	 Step : 3938000 	 Average Reward : 171.4433
# Episode : 4315 	 Step : 3940000 	 Average Reward : 107.6414
# Episode : 4317 	 Step : 3942000 	 Average Reward : 279.0241
# Episode : 4319 	 Step : 3944000 	 Average Reward : 282.8303
# Episode : 4321 	 Step : 3946000 	 Average Reward : 288.4109
# Episode : 4323 	 Step : 3948000 	 Average Reward : 282.1509
# Episode : 4325 	 Step : 3950000 	 Average Reward : 277.8211
# Episode : 4327 	 Step : 3952000 	 Average Reward : 222.3297
# Episode : 4330 	 Step : 3954000 	 Average Reward : 156.0424
# Episode : 4332 	 Step : 3956000 	 Average Reward : 279.0289
# Episode : 4334 	 Step : 3958000 	 Average Reward : 285.3291
# Episode : 4336 	 Step : 3960000 	 Average Reward : 284.3204
# Episode : 4338 	 Step : 3962000 	 Average Reward : 192.9512
# Episode : 4340 	 Step : 3964000 	 Average Reward : 263.8871
# Episode : 4342 	 Step : 3966000 	 Average Reward : 286.2289
# Episode : 4344 	 Step : 3968000 	 Average Reward : 283.0003
# Episode : 4346 	 Step : 3970000 	 Average Reward : 292.0371
# Episode : 4348 	 Step : 3972000 	 Average Reward : 288.2777
# Episode : 4350 	 Step : 3974000 	 Average Reward : 286.6556
# Episode : 4352 	 Step : 3976000 	 Average Reward : 279.131
# Episode : 4354 	 Step : 3978000 	 Average Reward : 157.305
# Episode : 4356 	 Step : 3980000 	 Average Reward : 280.4333
# Episode : 4358 	 Step : 3982000 	 Average Reward : 206.129
# Episode : 4360 	 Step : 3984000 	 Average Reward : 283.3119
# Episode : 4362 	 Step : 3986000 	 Average Reward : 284.3438
# Episode : 4364 	 Step : 3988000 	 Average Reward : 279.2271
# Episode : 4366 	 Step : 3990000 	 Average Reward : 284.5871
# Episode : 4369 	 Step : 3992000 	 Average Reward : 169.297
# Episode : 4371 	 Step : 3994000 	 Average Reward : 286.2038
# Episode : 4373 	 Step : 3996000 	 Average Reward : 279.4532
# Episode : 4375 	 Step : 3998000 	 Average Reward : 278.3688
# Episode : 4378 	 Step : 4000000 	 Average Reward : 167.4957
# Model Saved!!
