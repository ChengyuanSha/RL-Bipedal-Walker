# %% [markdown]
# Author: Chengyuan Sha
#
# Reference:
# Borrowed some ideas such as Open AI's actor-critic normalization tricks:
# https://github.com/pytorch/examples/blob/main/reinforcement_learning/actor_critic.py
# PPO formular and explanation:
# https://jonathan-hui.medium.com/rl-trust-region-policy-optimization-trpo-explained-a6ee04eeeee9
# OpenAI blog and github:
# https://openai.com/blog/openai-baselines-ppo/
# https://github.com/openai/baselines
# https://spinningup.openai.com/en/latest/algorithms/ppo.html

# %%
import numpy as np
import torch
import torch.nn as nn
import gym

# %%
seed = 100
torch.manual_seed(seed)
np.random.seed(seed)

# %%
# setting up GPU
try:
    device = torch.device("cuda")
    print("Current using GPU: ")
    print(torch.cuda.get_device_name(device))
except:
    print("GPU not connected. Please check your CUDA and required packages.")
# Out:
# Current using GPU:
# NVIDIA GeForce RTX 3090

# %%
class Buffer:
    """ replay buffer keep track of all variables needed for PPO """
    def __init__(self):
        self.actions = []
        self.states = []
        self.log_probability = []
        self.rewards = []
        self.is_finish = []

    def delete_all(self):
        del self.actions[:]
        del self.states[:]
        del self.log_probability[:]
        del self.rewards[:]
        del self.is_finish[:]

def MLP(state_dim, output_dim, hidden_dim = 64):
    """ define MLP for actor critic """
    return nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim),
            )

class AC(nn.Module):
    """ Actor Critic """
    def __init__(self, state_dim, action_dim):
        super(AC, self).__init__()
        self.action_dim = action_dim
        self.action_var = torch.full((action_dim,), 0.3).to(device) # 0.36 is the standard deviation
        self.actor = MLP(state_dim, action_dim)
        self.critic = MLP(state_dim, 1)

    def get_distribution(self, M, covariantM):
        return torch.distributions.MultivariateNormal(M, covariantM)

    def AC_action(self, state):
        distribution = self.get_distribution(self.actor(state), torch.diag(self.action_var).unsqueeze(dim=0))
        action = distribution.sample().detach()
        action_logprob = distribution.log_prob(action).detach()
        return action, action_logprob

    def AC_evaluate(self, state, action):
        action_mean = self.actor(state)
        covariantM = torch.diag_embed(self.action_var.expand_as(action_mean)).to(device)
        distribution = self.get_distribution(action_mean, covariantM)
        return distribution.log_prob(action), self.critic(state), distribution.entropy() # log_probability, state values, entropy


class PPO:
    """ Main PPO class """
    def __init__(self, state_dim, action_dim, lr_actor, lr_critic, gamma, num_of_epochs):
        self.gamma = gamma
        self.num_of_epochs = num_of_epochs
        self.buffer = Buffer()
        self.policy = AC(state_dim, action_dim).to(device)
        self.optimizer = torch.optim.Adam([
            {'params': self.policy.actor.parameters(), 'lr': lr_actor},
            {'params': self.policy.critic.parameters(), 'lr': lr_critic}
        ])
        self.policy_old = AC(state_dim, action_dim).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())

    def choose_action(self, state):
        with torch.no_grad():
            state = torch.FloatTensor(state).to(device)
            action, action_logprob = self.policy_old.AC_action(state)

        self.buffer.states.append(state)
        self.buffer.actions.append(action)
        self.buffer.log_probability.append(action_logprob)

        return action.detach().cpu().numpy().flatten()

    @staticmethod
    def normalize(reward):
        """ Reference:  Open AI's actor-critic Trick """
        rewards = torch.tensor(reward, dtype=torch.float32).to(device)
        return (rewards - rewards.mean()) / (rewards.std() + 1e-7)

    def monte_carlo_estimation(self):
        """ monte carlo estimation """
        rewards = []
        gamma_reward = 0
        for reward, is_finish in zip(self.buffer.rewards[::-1], self.buffer.is_finish[::-1]):
            if is_finish:
                gamma_reward = 0
            gamma_reward = reward + (self.gamma * gamma_reward)
            rewards.append(gamma_reward)
        return rewards[::-1]
    
    @staticmethod
    def get_tensor(tensor):
        return torch.squeeze(torch.stack(tensor, dim=0)).detach().to(device)

    def update_PPO(self):
        rewards = self.monte_carlo_estimation()
        # Open AI's actor-critic Normalizing Trick
        rewards = PPO.normalize(rewards)
        past_states, past_actions, past_logprobs = PPO.get_tensor(self.buffer.states), PPO.get_tensor(self.buffer.actions), PPO.get_tensor(self.buffer.log_probability)  
        # Main update loop according to the pseudocode formula
        for _ in range(self.num_of_epochs):
            log_probability, state_values, entropy = self.policy.AC_evaluate(past_states, past_actions)
            state_values = torch.squeeze(state_values)
            ratios = torch.exp(log_probability - past_logprobs.detach())
            # Surrogate Loss calculation
            advantages = rewards - state_values.detach()
            surrogate_loss1 = ratios * advantages
            surrogate_loss2 = torch.clamp(ratios, 0.8, 1.2) * advantages # clip the loss
            # computed the total loss
            loss = -torch.min(surrogate_loss1, surrogate_loss2) + 0.5 * nn.MSELoss()(state_values, rewards) - 0.01 * entropy
            # gradient optimization
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
        # cleaning and reinit
        self.policy_old.load_state_dict(self.policy.state_dict())
        self.buffer.delete_all()

    def save_model(self, save_path):
        """ save model to pth file """
        torch.save(self.policy_old.state_dict(), save_path)

# %% [markdown]
# Setting hyperparameters & gym environment

# %%
# hyper parameters
hp = {'max_ep_len': 1000, 'max_steps': 10000000,
      'update_step': 4000, 'num_of_epochs': 80,  'gamma': 0.99,
      'lr_actor': 0.0003, 'lr_critic':0.001 }

# %%
# creating bipedal walker environment
env = gym.make('BipedalWalker-v3')

# %%
# state
state_dim = env.observation_space.shape[0]
# action
action_dim = env.action_space.shape[0]

hp['action_dim'] = action_dim
hp['state_dim'] = state_dim

# %%
action_dim
# Out:
# 4

# %% [markdown]
# Training PPO:

# %%
def train(hp):
    # logging file
    file_log = open('PPO_record.csv',"w+")
    file_log.write('episode,step,reward\n')
    # init PPO agent
    ppo = PPO(hp['state_dim'], hp['action_dim'], hp['lr_actor'], hp['lr_critic'], hp['gamma'],
              hp['num_of_epochs'])
    # init recording variables
    reward_logging, episode_logging, step, episode = 0, 0, 0, 0

    # main training loop
    while step <= hp['max_steps']:
        state = env.reset()
        reward_cur_episode = 0
        for _ in range(1, hp['max_ep_len']+1):
            action = ppo.choose_action(state)
            state, reward, is_finish, extra_info = env.step(action)
            # append to record buffer
            ppo.buffer.rewards.append(reward)
            ppo.buffer.is_finish.append(is_finish)
            step +=1
            reward_cur_episode += reward
            if step % hp['update_step'] == 0:
                ppo.update_PPO() # update PPO
            if step % 10000 == 0: # log & print training info
                avg_reward = round(reward_logging / episode_logging, 4)
                to_print = '{},{},{}\n'.format(episode, step, avg_reward)
                print("Episode : {} \t Step : {} \t Average Reward : {}".format(episode, step, avg_reward))
                file_log.write(to_print)
                file_log.flush()
                reward_logging, episode_logging = 0, 0
            if step % 200000 == 0:  # save model to pth
                ppo.save_model("trained_model.pth")
                print("Model Saved!!")
            if is_finish: # die
                break
        reward_logging += reward_cur_episode
        episode_logging += 1
        episode += 1
    # close file and environment
    file_log.close()
    env.close()

train(hp)
# Out:
# Episode : 21 	 Step : 10000 	 Average Reward : -79.3622
# Episode : 51 	 Step : 20000 	 Average Reward : -92.08
# Episode : 65 	 Step : 30000 	 Average Reward : -68.2491
# Episode : 80 	 Step : 40000 	 Average Reward : -66.5355
# Episode : 91 	 Step : 50000 	 Average Reward : -50.7546
# Episode : 101 	 Step : 60000 	 Average Reward : -46.1439
# Episode : 111 	 Step : 70000 	 Average Reward : -43.5613
# Episode : 123 	 Step : 80000 	 Average Reward : -53.6664
# Episode : 134 	 Step : 90000 	 Average Reward : -56.7611
# Episode : 147 	 Step : 100000 	 Average Reward : -58.1861
# Episode : 158 	 Step : 110000 	 Average Reward : -49.8527
# Episode : 170 	 Step : 120000 	 Average Reward : -51.5806
# Episode : 182 	 Step : 130000 	 Average Reward : -52.1855
# Episode : 193 	 Step : 140000 	 Average Reward : -52.8095
# Episode : 206 	 Step : 150000 	 Average Reward : -57.6537
# Episode : 220 	 Step : 160000 	 Average Reward : -61.4379
# Episode : 231 	 Step : 170000 	 Average Reward : -46.6372
# Episode : 241 	 Step : 180000 	 Average Reward : -37.92
# Episode : 254 	 Step : 190000 	 Average Reward : -61.5799
# Episode : 264 	 Step : 200000 	 Average Reward : -37.7298
# Model Saved!!
# Episode : 275 	 Step : 210000 	 Average Reward : -43.9616
# Episode : 286 	 Step : 220000 	 Average Reward : -42.2962
# Episode : 298 	 Step : 230000 	 Average Reward : -45.5881
# Episode : 309 	 Step : 240000 	 Average Reward : -38.4704
# Episode : 321 	 Step : 250000 	 Average Reward : -44.332
# Episode : 336 	 Step : 260000 	 Average Reward : -62.2691
# Episode : 347 	 Step : 270000 	 Average Reward : -32.6478
# Episode : 359 	 Step : 280000 	 Average Reward : -39.3523
# Episode : 373 	 Step : 290000 	 Average Reward : -45.9712
# Episode : 384 	 Step : 300000 	 Average Reward : -29.7979
# Episode : 394 	 Step : 310000 	 Average Reward : -17.0539
# Episode : 404 	 Step : 320000 	 Average Reward : -11.6915
# Episode : 416 	 Step : 330000 	 Average Reward : -33.7067
# Episode : 427 	 Step : 340000 	 Average Reward : -15.5762
# Episode : 437 	 Step : 350000 	 Average Reward : -3.6369
# Episode : 451 	 Step : 360000 	 Average Reward : -35.4224
# Episode : 464 	 Step : 370000 	 Average Reward : -47.4088
# Episode : 474 	 Step : 380000 	 Average Reward : -7.661
# Episode : 484 	 Step : 390000 	 Average Reward : 10.8698
# Episode : 496 	 Step : 400000 	 Average Reward : -9.219
# Model Saved!!
# Episode : 506 	 Step : 410000 	 Average Reward : 15.5753
# Episode : 516 	 Step : 420000 	 Average Reward : 18.0056
# Episode : 527 	 Step : 430000 	 Average Reward : 5.2745
# Episode : 538 	 Step : 440000 	 Average Reward : 11.1961
# Episode : 548 	 Step : 450000 	 Average Reward : 17.6164
# Episode : 558 	 Step : 460000 	 Average Reward : 33.4375
# Episode : 568 	 Step : 470000 	 Average Reward : 39.413
# Episode : 578 	 Step : 480000 	 Average Reward : 27.9554
# Episode : 589 	 Step : 490000 	 Average Reward : 20.3104
# Episode : 601 	 Step : 500000 	 Average Reward : 13.8091
# Episode : 611 	 Step : 510000 	 Average Reward : 31.3417
# Episode : 622 	 Step : 520000 	 Average Reward : 22.1678
# Episode : 632 	 Step : 530000 	 Average Reward : 59.8745
# Episode : 642 	 Step : 540000 	 Average Reward : 57.9031
# Episode : 653 	 Step : 550000 	 Average Reward : 39.5135
# Episode : 663 	 Step : 560000 	 Average Reward : 68.0531
# Episode : 673 	 Step : 570000 	 Average Reward : 70.8888
# Episode : 683 	 Step : 580000 	 Average Reward : 78.1048
# Episode : 693 	 Step : 590000 	 Average Reward : 83.0073
# Episode : 705 	 Step : 600000 	 Average Reward : 54.017
# Model Saved!!
# Episode : 718 	 Step : 610000 	 Average Reward : 30.524
# Episode : 729 	 Step : 620000 	 Average Reward : 72.3467
# Episode : 740 	 Step : 630000 	 Average Reward : 56.187
# Episode : 751 	 Step : 640000 	 Average Reward : 67.5013
# Episode : 761 	 Step : 650000 	 Average Reward : 77.5814
# Episode : 771 	 Step : 660000 	 Average Reward : 74.288
# Episode : 782 	 Step : 670000 	 Average Reward : 79.6226
# Episode : 792 	 Step : 680000 	 Average Reward : 102.0666
# Episode : 803 	 Step : 690000 	 Average Reward : 78.3348
# Episode : 814 	 Step : 700000 	 Average Reward : 76.4723
# Episode : 825 	 Step : 710000 	 Average Reward : 80.8662
# Episode : 836 	 Step : 720000 	 Average Reward : 81.0986
# Episode : 846 	 Step : 730000 	 Average Reward : 103.2888
# Episode : 856 	 Step : 740000 	 Average Reward : 102.2877
# Episode : 866 	 Step : 750000 	 Average Reward : 104.9737
# Episode : 876 	 Step : 760000 	 Average Reward : 112.2818
# Episode : 886 	 Step : 770000 	 Average Reward : 115.1968
# Episode : 896 	 Step : 780000 	 Average Reward : 100.8159
# Episode : 906 	 Step : 790000 	 Average Reward : 112.178
# Episode : 917 	 Step : 800000 	 Average Reward : 90.1926
# Model Saved!!
# Episode : 929 	 Step : 810000 	 Average Reward : 71.4402
# Episode : 939 	 Step : 820000 	 Average Reward : 96.3506
# Episode : 950 	 Step : 830000 	 Average Reward : 90.4375
# Episode : 960 	 Step : 840000 	 Average Reward : 107.7514
# Episode : 970 	 Step : 850000 	 Average Reward : 107.496
# Episode : 980 	 Step : 860000 	 Average Reward : 110.4206
# Episode : 990 	 Step : 870000 	 Average Reward : 115.8903
# Episode : 1001 	 Step : 880000 	 Average Reward : 89.8772
# Episode : 1011 	 Step : 890000 	 Average Reward : 116.4388
# Episode : 1022 	 Step : 900000 	 Average Reward : 79.2957
# Episode : 1032 	 Step : 910000 	 Average Reward : 98.3508
# Episode : 1042 	 Step : 920000 	 Average Reward : 113.731
# Episode : 1052 	 Step : 930000 	 Average Reward : 119.1688
# Episode : 1064 	 Step : 940000 	 Average Reward : 83.9853
# Episode : 1074 	 Step : 950000 	 Average Reward : 115.468
# Episode : 1084 	 Step : 960000 	 Average Reward : 94.9681
# Episode : 1095 	 Step : 970000 	 Average Reward : 98.6007
# Episode : 1108 	 Step : 980000 	 Average Reward : 66.105
# Episode : 1118 	 Step : 990000 	 Average Reward : 117.3014
# Episode : 1128 	 Step : 1000000 	 Average Reward : 116.1392
# Model Saved!!
# Episode : 1138 	 Step : 1010000 	 Average Reward : 121.9351
# Episode : 1148 	 Step : 1020000 	 Average Reward : 121.2064
# Episode : 1158 	 Step : 1030000 	 Average Reward : 125.3481
# Episode : 1168 	 Step : 1040000 	 Average Reward : 100.5971
# Episode : 1179 	 Step : 1050000 	 Average Reward : 113.1862
# Episode : 1189 	 Step : 1060000 	 Average Reward : 111.2788
# Episode : 1200 	 Step : 1070000 	 Average Reward : 107.9447
# Episode : 1210 	 Step : 1080000 	 Average Reward : 122.9754
# Episode : 1221 	 Step : 1090000 	 Average Reward : 103.8367
# Episode : 1232 	 Step : 1100000 	 Average Reward : 102.6719
# Episode : 1242 	 Step : 1110000 	 Average Reward : 125.5215
# Episode : 1252 	 Step : 1120000 	 Average Reward : 110.3896
# Episode : 1262 	 Step : 1130000 	 Average Reward : 128.8241
# Episode : 1272 	 Step : 1140000 	 Average Reward : 126.7392
# Episode : 1282 	 Step : 1150000 	 Average Reward : 130.3962
# Episode : 1292 	 Step : 1160000 	 Average Reward : 93.4632
# Episode : 1302 	 Step : 1170000 	 Average Reward : 133.7874
# Episode : 1312 	 Step : 1180000 	 Average Reward : 117.7902
# Episode : 1324 	 Step : 1190000 	 Average Reward : 95.1043
# Episode : 1334 	 Step : 1200000 	 Average Reward : 131.6907
# Model Saved!!
# Episode : 1344 	 Step : 1210000 	 Average Reward : 135.893
# Episode : 1354 	 Step : 1220000 	 Average Reward : 130.7273
# Episode : 1364 	 Step : 1230000 	 Average Reward : 112.5818
# Episode : 1375 	 Step : 1240000 	 Average Reward : 119.29
# Episode : 1385 	 Step : 1250000 	 Average Reward : 120.3944
# Episode : 1395 	 Step : 1260000 	 Average Reward : 140.3986
# Episode : 1405 	 Step : 1270000 	 Average Reward : 139.5768
# Episode : 1415 	 Step : 1280000 	 Average Reward : 141.0366
# Episode : 1425 	 Step : 1290000 	 Average Reward : 142.2468
# Episode : 1435 	 Step : 1300000 	 Average Reward : 129.7292
# Episode : 1445 	 Step : 1310000 	 Average Reward : 122.5726
# Episode : 1456 	 Step : 1320000 	 Average Reward : 122.6606
# Episode : 1466 	 Step : 1330000 	 Average Reward : 140.1754
# Episode : 1476 	 Step : 1340000 	 Average Reward : 140.2832
# Episode : 1486 	 Step : 1350000 	 Average Reward : 141.6751
# Episode : 1496 	 Step : 1360000 	 Average Reward : 141.5528
# Episode : 1506 	 Step : 1370000 	 Average Reward : 142.8425
# Episode : 1516 	 Step : 1380000 	 Average Reward : 126.2292
# Episode : 1527 	 Step : 1390000 	 Average Reward : 119.9828
# Episode : 1537 	 Step : 1400000 	 Average Reward : 145.817
# Model Saved!!
# Episode : 1547 	 Step : 1410000 	 Average Reward : 142.509
# Episode : 1557 	 Step : 1420000 	 Average Reward : 131.7917
# Episode : 1567 	 Step : 1430000 	 Average Reward : 145.1127
# Episode : 1579 	 Step : 1440000 	 Average Reward : 90.8613
# Episode : 1589 	 Step : 1450000 	 Average Reward : 141.0494
# Episode : 1599 	 Step : 1460000 	 Average Reward : 138.7528
# Episode : 1609 	 Step : 1470000 	 Average Reward : 119.1088
# Episode : 1620 	 Step : 1480000 	 Average Reward : 118.057
# Episode : 1630 	 Step : 1490000 	 Average Reward : 141.9362
# Episode : 1640 	 Step : 1500000 	 Average Reward : 139.1685
# Episode : 1650 	 Step : 1510000 	 Average Reward : 142.7895
# Episode : 1660 	 Step : 1520000 	 Average Reward : 116.8841
# Episode : 1670 	 Step : 1530000 	 Average Reward : 137.3025
# Episode : 1680 	 Step : 1540000 	 Average Reward : 140.5374
# Episode : 1690 	 Step : 1550000 	 Average Reward : 144.5366
# Episode : 1700 	 Step : 1560000 	 Average Reward : 144.5927
# Episode : 1710 	 Step : 1570000 	 Average Reward : 145.9125
# Episode : 1720 	 Step : 1580000 	 Average Reward : 145.4849
# Episode : 1730 	 Step : 1590000 	 Average Reward : 146.0177
# Episode : 1740 	 Step : 1600000 	 Average Reward : 146.4025
# Model Saved!!
# Episode : 1750 	 Step : 1610000 	 Average Reward : 143.7452
# Episode : 1760 	 Step : 1620000 	 Average Reward : 142.1249
# Episode : 1771 	 Step : 1630000 	 Average Reward : 125.4071
# Episode : 1782 	 Step : 1640000 	 Average Reward : 104.7095
# Episode : 1792 	 Step : 1650000 	 Average Reward : 145.4212
# Episode : 1802 	 Step : 1660000 	 Average Reward : 110.2356
# Episode : 1812 	 Step : 1670000 	 Average Reward : 142.7674
# Episode : 1823 	 Step : 1680000 	 Average Reward : 123.0185
# Episode : 1833 	 Step : 1690000 	 Average Reward : 130.1036
# Episode : 1843 	 Step : 1700000 	 Average Reward : 139.4606
# Episode : 1853 	 Step : 1710000 	 Average Reward : 144.6134
# Episode : 1864 	 Step : 1720000 	 Average Reward : 122.6038
# Episode : 1874 	 Step : 1730000 	 Average Reward : 128.8397
# Episode : 1884 	 Step : 1740000 	 Average Reward : 142.8976
# Episode : 1895 	 Step : 1750000 	 Average Reward : 123.2474
# Episode : 1905 	 Step : 1760000 	 Average Reward : 129.6871
# Episode : 1915 	 Step : 1770000 	 Average Reward : 146.6395
# Episode : 1925 	 Step : 1780000 	 Average Reward : 143.8237
# Episode : 1935 	 Step : 1790000 	 Average Reward : 125.3462
# Episode : 1946 	 Step : 1800000 	 Average Reward : 128.7535
# Model Saved!!
# Episode : 1957 	 Step : 1810000 	 Average Reward : 118.2627
# Episode : 1967 	 Step : 1820000 	 Average Reward : 130.8558
# Episode : 1979 	 Step : 1830000 	 Average Reward : 103.4872
# Episode : 1989 	 Step : 1840000 	 Average Reward : 144.359
# Episode : 2000 	 Step : 1850000 	 Average Reward : 106.0705
# Episode : 2011 	 Step : 1860000 	 Average Reward : 99.2393
# Episode : 2022 	 Step : 1870000 	 Average Reward : 106.1766
# Episode : 2033 	 Step : 1880000 	 Average Reward : 119.8958
# Episode : 2043 	 Step : 1890000 	 Average Reward : 132.0888
# Episode : 2054 	 Step : 1900000 	 Average Reward : 124.6504
# Episode : 2064 	 Step : 1910000 	 Average Reward : 141.468
# Episode : 2074 	 Step : 1920000 	 Average Reward : 140.2693
# Episode : 2084 	 Step : 1930000 	 Average Reward : 145.4335
# Episode : 2095 	 Step : 1940000 	 Average Reward : 120.3687
# Episode : 2105 	 Step : 1950000 	 Average Reward : 118.3158
# Episode : 2117 	 Step : 1960000 	 Average Reward : 97.9594
# Episode : 2127 	 Step : 1970000 	 Average Reward : 143.6126
# Episode : 2137 	 Step : 1980000 	 Average Reward : 121.8188
# Episode : 2148 	 Step : 1990000 	 Average Reward : 132.3205
# Episode : 2158 	 Step : 2000000 	 Average Reward : 144.9093
# Model Saved!!
# Episode : 2168 	 Step : 2010000 	 Average Reward : 149.1136
# Episode : 2178 	 Step : 2020000 	 Average Reward : 152.7075
# Episode : 2188 	 Step : 2030000 	 Average Reward : 153.3213
# Episode : 2198 	 Step : 2040000 	 Average Reward : 128.7085
# Episode : 2210 	 Step : 2050000 	 Average Reward : 106.729
# Episode : 2220 	 Step : 2060000 	 Average Reward : 152.1951
# Episode : 2230 	 Step : 2070000 	 Average Reward : 152.4502
# Episode : 2240 	 Step : 2080000 	 Average Reward : 148.3063
# Episode : 2251 	 Step : 2090000 	 Average Reward : 111.2223
# Episode : 2262 	 Step : 2100000 	 Average Reward : 114.105
# Episode : 2274 	 Step : 2110000 	 Average Reward : 99.4838
# Episode : 2285 	 Step : 2120000 	 Average Reward : 105.164
# Episode : 2296 	 Step : 2130000 	 Average Reward : 135.385
# Episode : 2307 	 Step : 2140000 	 Average Reward : 117.8592
# Episode : 2317 	 Step : 2150000 	 Average Reward : 136.2355
# Episode : 2328 	 Step : 2160000 	 Average Reward : 145.7707
# Episode : 2339 	 Step : 2170000 	 Average Reward : 105.2653
# Episode : 2349 	 Step : 2180000 	 Average Reward : 148.6953
# Episode : 2361 	 Step : 2190000 	 Average Reward : 94.5447
# Episode : 2373 	 Step : 2200000 	 Average Reward : 102.2573
# Model Saved!!
# Episode : 2383 	 Step : 2210000 	 Average Reward : 152.0534
# Episode : 2395 	 Step : 2220000 	 Average Reward : 71.6622
# Episode : 2406 	 Step : 2230000 	 Average Reward : 129.4215
# Episode : 2417 	 Step : 2240000 	 Average Reward : 114.9322
# Episode : 2427 	 Step : 2250000 	 Average Reward : 151.3825
# Episode : 2438 	 Step : 2260000 	 Average Reward : 113.5763
# Episode : 2453 	 Step : 2270000 	 Average Reward : 40.1733
# Episode : 2464 	 Step : 2280000 	 Average Reward : 98.4797
# Episode : 2477 	 Step : 2290000 	 Average Reward : 57.7078
# Episode : 2488 	 Step : 2300000 	 Average Reward : 110.7538
# Episode : 2500 	 Step : 2310000 	 Average Reward : 107.5719
# Episode : 2512 	 Step : 2320000 	 Average Reward : 83.3086
# Episode : 2525 	 Step : 2330000 	 Average Reward : 68.4962
# Episode : 2535 	 Step : 2340000 	 Average Reward : 133.6663
# Episode : 2546 	 Step : 2350000 	 Average Reward : 85.8966
# Episode : 2559 	 Step : 2360000 	 Average Reward : 51.068
# Episode : 2569 	 Step : 2370000 	 Average Reward : 148.6994
# Episode : 2581 	 Step : 2380000 	 Average Reward : 102.1981
# Episode : 2595 	 Step : 2390000 	 Average Reward : 35.606
# Episode : 2606 	 Step : 2400000 	 Average Reward : 123.4556
# Model Saved!!
# Episode : 2618 	 Step : 2410000 	 Average Reward : 94.1089
# Episode : 2629 	 Step : 2420000 	 Average Reward : 115.6252
# Episode : 2641 	 Step : 2430000 	 Average Reward : 90.5195
# Episode : 2652 	 Step : 2440000 	 Average Reward : 102.6717
# Episode : 2664 	 Step : 2450000 	 Average Reward : 79.0274
# Episode : 2677 	 Step : 2460000 	 Average Reward : 65.4907
# Episode : 2691 	 Step : 2470000 	 Average Reward : 46.2016
# Episode : 2703 	 Step : 2480000 	 Average Reward : 109.197
# Episode : 2714 	 Step : 2490000 	 Average Reward : 100.2607
# Episode : 2726 	 Step : 2500000 	 Average Reward : 79.9378
# Episode : 2738 	 Step : 2510000 	 Average Reward : 100.5185
# Episode : 2749 	 Step : 2520000 	 Average Reward : 113.67
# Episode : 2761 	 Step : 2530000 	 Average Reward : 91.145
# Episode : 2772 	 Step : 2540000 	 Average Reward : 96.0639
# Episode : 2783 	 Step : 2550000 	 Average Reward : 120.5164
# Episode : 2794 	 Step : 2560000 	 Average Reward : 117.6257
# Episode : 2806 	 Step : 2570000 	 Average Reward : 97.6044
# Episode : 2817 	 Step : 2580000 	 Average Reward : 106.3404
# Episode : 2830 	 Step : 2590000 	 Average Reward : 87.016
# Episode : 2841 	 Step : 2600000 	 Average Reward : 113.8912
# Model Saved!!
# Episode : 2854 	 Step : 2610000 	 Average Reward : 55.1711
# Episode : 2866 	 Step : 2620000 	 Average Reward : 100.659
# Episode : 2877 	 Step : 2630000 	 Average Reward : 141.6864
# Episode : 2888 	 Step : 2640000 	 Average Reward : 110.2029
# Episode : 2898 	 Step : 2650000 	 Average Reward : 104.8995
# Episode : 2908 	 Step : 2660000 	 Average Reward : 155.6316
# Episode : 2920 	 Step : 2670000 	 Average Reward : 120.2547
# Episode : 2931 	 Step : 2680000 	 Average Reward : 108.446
# Episode : 2942 	 Step : 2690000 	 Average Reward : 127.2169
# Episode : 2953 	 Step : 2700000 	 Average Reward : 119.9597
# Episode : 2963 	 Step : 2710000 	 Average Reward : 116.6542
# Episode : 2974 	 Step : 2720000 	 Average Reward : 127.0344
# Episode : 2986 	 Step : 2730000 	 Average Reward : 115.5788
# Episode : 2997 	 Step : 2740000 	 Average Reward : 125.812
# Episode : 3007 	 Step : 2750000 	 Average Reward : 160.7599
# Episode : 3017 	 Step : 2760000 	 Average Reward : 134.0466
# Episode : 3029 	 Step : 2770000 	 Average Reward : 114.0924
# Episode : 3042 	 Step : 2780000 	 Average Reward : 87.1476
# Episode : 3053 	 Step : 2790000 	 Average Reward : 137.9249
# Episode : 3063 	 Step : 2800000 	 Average Reward : 136.7158
# Model Saved!!
# Episode : 3074 	 Step : 2810000 	 Average Reward : 139.019
# Episode : 3084 	 Step : 2820000 	 Average Reward : 162.0998
# Episode : 3094 	 Step : 2830000 	 Average Reward : 163.0254
# Episode : 3105 	 Step : 2840000 	 Average Reward : 115.7009
# Episode : 3117 	 Step : 2850000 	 Average Reward : 120.7675
# Episode : 3128 	 Step : 2860000 	 Average Reward : 122.5552
# Episode : 3139 	 Step : 2870000 	 Average Reward : 105.3472
# Episode : 3149 	 Step : 2880000 	 Average Reward : 161.8034
# Episode : 3162 	 Step : 2890000 	 Average Reward : 95.3662
# Episode : 3174 	 Step : 2900000 	 Average Reward : 114.3274
# Episode : 3184 	 Step : 2910000 	 Average Reward : 145.1781
# Episode : 3194 	 Step : 2920000 	 Average Reward : 145.4465
# Episode : 3207 	 Step : 2930000 	 Average Reward : 79.7125
# Episode : 3217 	 Step : 2940000 	 Average Reward : 155.42
# Episode : 3232 	 Step : 2950000 	 Average Reward : 26.3069
# Episode : 3243 	 Step : 2960000 	 Average Reward : 121.6787
# Episode : 3253 	 Step : 2970000 	 Average Reward : 148.1123
# Episode : 3265 	 Step : 2980000 	 Average Reward : 109.3881
# Episode : 3276 	 Step : 2990000 	 Average Reward : 104.6775
# Episode : 3288 	 Step : 3000000 	 Average Reward : 126.2507
# Model Saved!!
# Episode : 3300 	 Step : 3010000 	 Average Reward : 110.4927
# Episode : 3311 	 Step : 3020000 	 Average Reward : 81.2199
# Episode : 3324 	 Step : 3030000 	 Average Reward : 91.1908
# Episode : 3337 	 Step : 3040000 	 Average Reward : 81.5646
# Episode : 3349 	 Step : 3050000 	 Average Reward : 97.5996
# Episode : 3365 	 Step : 3060000 	 Average Reward : 45.2706
# Episode : 3377 	 Step : 3070000 	 Average Reward : 104.3731
# Episode : 3388 	 Step : 3080000 	 Average Reward : 108.97
# Episode : 3399 	 Step : 3090000 	 Average Reward : 104.9945
# Episode : 3409 	 Step : 3100000 	 Average Reward : 148.8386
# Episode : 3420 	 Step : 3110000 	 Average Reward : 138.0295
# Episode : 3431 	 Step : 3120000 	 Average Reward : 117.749
# Episode : 3444 	 Step : 3130000 	 Average Reward : 73.431
# Episode : 3455 	 Step : 3140000 	 Average Reward : 121.0184
# Episode : 3468 	 Step : 3150000 	 Average Reward : 78.6195
# Episode : 3479 	 Step : 3160000 	 Average Reward : 131.359
# Episode : 3491 	 Step : 3170000 	 Average Reward : 85.5367
# Episode : 3502 	 Step : 3180000 	 Average Reward : 117.6467
# Episode : 3512 	 Step : 3190000 	 Average Reward : 153.6515
# Episode : 3523 	 Step : 3200000 	 Average Reward : 129.7181
# Model Saved!!
# Episode : 3533 	 Step : 3210000 	 Average Reward : 171.5869
# Episode : 3545 	 Step : 3220000 	 Average Reward : 105.1134
# Episode : 3556 	 Step : 3230000 	 Average Reward : 121.8719
# Episode : 3566 	 Step : 3240000 	 Average Reward : 159.1649
# Episode : 3577 	 Step : 3250000 	 Average Reward : 139.5035
# Episode : 3587 	 Step : 3260000 	 Average Reward : 134.6763
# Episode : 3600 	 Step : 3270000 	 Average Reward : 86.7968
# Episode : 3611 	 Step : 3280000 	 Average Reward : 113.3514
# Episode : 3625 	 Step : 3290000 	 Average Reward : 30.153
# Episode : 3636 	 Step : 3300000 	 Average Reward : 112.9047
# Episode : 3649 	 Step : 3310000 	 Average Reward : 93.2001
# Episode : 3660 	 Step : 3320000 	 Average Reward : 124.7534
# Episode : 3672 	 Step : 3330000 	 Average Reward : 91.577
# Episode : 3682 	 Step : 3340000 	 Average Reward : 173.5838
# Episode : 3694 	 Step : 3350000 	 Average Reward : 122.2265
# Episode : 3706 	 Step : 3360000 	 Average Reward : 97.5742
# Episode : 3716 	 Step : 3370000 	 Average Reward : 139.6085
# Episode : 3728 	 Step : 3380000 	 Average Reward : 125.9156
# Episode : 3738 	 Step : 3390000 	 Average Reward : 173.3239
# Episode : 3749 	 Step : 3400000 	 Average Reward : 129.3239
# Model Saved!!
# Episode : 3760 	 Step : 3410000 	 Average Reward : 130.0082
# Episode : 3772 	 Step : 3420000 	 Average Reward : 100.6521
# Episode : 3784 	 Step : 3430000 	 Average Reward : 105.1628
# Episode : 3795 	 Step : 3440000 	 Average Reward : 142.1087
# Episode : 3807 	 Step : 3450000 	 Average Reward : 121.1085
# Episode : 3818 	 Step : 3460000 	 Average Reward : 104.6211
# Episode : 3829 	 Step : 3470000 	 Average Reward : 147.6001
# Episode : 3839 	 Step : 3480000 	 Average Reward : 174.35
# Episode : 3851 	 Step : 3490000 	 Average Reward : 127.7231
# Episode : 3862 	 Step : 3500000 	 Average Reward : 107.5308
# Episode : 3875 	 Step : 3510000 	 Average Reward : 90.281
# Episode : 3886 	 Step : 3520000 	 Average Reward : 125.1852
# Episode : 3896 	 Step : 3530000 	 Average Reward : 181.9337
# Episode : 3907 	 Step : 3540000 	 Average Reward : 159.847
# Episode : 3917 	 Step : 3550000 	 Average Reward : 182.4629
# Episode : 3928 	 Step : 3560000 	 Average Reward : 159.1801
# Episode : 3938 	 Step : 3570000 	 Average Reward : 157.002
# Episode : 3948 	 Step : 3580000 	 Average Reward : 183.0585
# Episode : 3960 	 Step : 3590000 	 Average Reward : 109.122
# Episode : 3971 	 Step : 3600000 	 Average Reward : 140.308
# Model Saved!!
# Episode : 3982 	 Step : 3610000 	 Average Reward : 143.2243
# Episode : 3992 	 Step : 3620000 	 Average Reward : 184.54
# Episode : 4002 	 Step : 3630000 	 Average Reward : 147.7802
# Episode : 4014 	 Step : 3640000 	 Average Reward : 115.1313
# Episode : 4025 	 Step : 3650000 	 Average Reward : 157.8458
# Episode : 4036 	 Step : 3660000 	 Average Reward : 153.6539
# Episode : 4046 	 Step : 3670000 	 Average Reward : 180.2493
# Episode : 4057 	 Step : 3680000 	 Average Reward : 140.7372
# Episode : 4067 	 Step : 3690000 	 Average Reward : 169.1199
# Episode : 4079 	 Step : 3700000 	 Average Reward : 124.0774
# Episode : 4091 	 Step : 3710000 	 Average Reward : 111.5494
# Episode : 4102 	 Step : 3720000 	 Average Reward : 147.128
# Episode : 4113 	 Step : 3730000 	 Average Reward : 149.4044
# Episode : 4124 	 Step : 3740000 	 Average Reward : 132.5958
# Episode : 4135 	 Step : 3750000 	 Average Reward : 149.1021
# Episode : 4146 	 Step : 3760000 	 Average Reward : 143.0151
# Episode : 4156 	 Step : 3770000 	 Average Reward : 195.5703
# Episode : 4171 	 Step : 3780000 	 Average Reward : 48.6565
# Episode : 4182 	 Step : 3790000 	 Average Reward : 106.4655
# Episode : 4194 	 Step : 3800000 	 Average Reward : 135.8699
# Model Saved!!
# Episode : 4205 	 Step : 3810000 	 Average Reward : 147.2829
# Episode : 4216 	 Step : 3820000 	 Average Reward : 137.3633
# Episode : 4230 	 Step : 3830000 	 Average Reward : 90.0366
# Episode : 4240 	 Step : 3840000 	 Average Reward : 165.4333
# Episode : 4252 	 Step : 3850000 	 Average Reward : 110.3957
# Episode : 4262 	 Step : 3860000 	 Average Reward : 175.2975
# Episode : 4273 	 Step : 3870000 	 Average Reward : 157.0256
# Episode : 4284 	 Step : 3880000 	 Average Reward : 150.5276
# Episode : 4294 	 Step : 3890000 	 Average Reward : 188.568
# Episode : 4305 	 Step : 3900000 	 Average Reward : 150.7076
# Episode : 4318 	 Step : 3910000 	 Average Reward : 101.3147
# Episode : 4328 	 Step : 3920000 	 Average Reward : 185.3863
# Episode : 4339 	 Step : 3930000 	 Average Reward : 151.5923
# Episode : 4350 	 Step : 3940000 	 Average Reward : 141.0457
# Episode : 4363 	 Step : 3950000 	 Average Reward : 88.134
# Episode : 4375 	 Step : 3960000 	 Average Reward : 101.0814
# Episode : 4386 	 Step : 3970000 	 Average Reward : 160.9473
# Episode : 4397 	 Step : 3980000 	 Average Reward : 146.3567
# Episode : 4410 	 Step : 3990000 	 Average Reward : 86.4514
# Episode : 4422 	 Step : 4000000 	 Average Reward : 134.9174
# Model Saved!!
# Episode : 4433 	 Step : 4010000 	 Average Reward : 135.3589
# Episode : 4445 	 Step : 4020000 	 Average Reward : 123.6053
# Episode : 4456 	 Step : 4030000 	 Average Reward : 143.1036
# Episode : 4468 	 Step : 4040000 	 Average Reward : 140.125
# Episode : 4480 	 Step : 4050000 	 Average Reward : 122.906
# Episode : 4491 	 Step : 4060000 	 Average Reward : 159.2904
# Episode : 4502 	 Step : 4070000 	 Average Reward : 130.7364
# Episode : 4513 	 Step : 4080000 	 Average Reward : 156.0012
# Episode : 4525 	 Step : 4090000 	 Average Reward : 130.628
# Episode : 4537 	 Step : 4100000 	 Average Reward : 137.8303
# Episode : 4548 	 Step : 4110000 	 Average Reward : 142.4762
# Episode : 4560 	 Step : 4120000 	 Average Reward : 132.5132
# Episode : 4570 	 Step : 4130000 	 Average Reward : 178.4868
# Episode : 4581 	 Step : 4140000 	 Average Reward : 175.1561
# Episode : 4591 	 Step : 4150000 	 Average Reward : 171.7229
# Episode : 4602 	 Step : 4160000 	 Average Reward : 153.9314
# Episode : 4614 	 Step : 4170000 	 Average Reward : 138.0505
# Episode : 4625 	 Step : 4180000 	 Average Reward : 157.8017
# Episode : 4635 	 Step : 4190000 	 Average Reward : 189.6951
# Episode : 4645 	 Step : 4200000 	 Average Reward : 177.3847
# Model Saved!!
# Episode : 4655 	 Step : 4210000 	 Average Reward : 192.1488
# Episode : 4665 	 Step : 4220000 	 Average Reward : 193.5605
# Episode : 4676 	 Step : 4230000 	 Average Reward : 154.592
# Episode : 4687 	 Step : 4240000 	 Average Reward : 164.5702
# Episode : 4698 	 Step : 4250000 	 Average Reward : 149.2394
# Episode : 4709 	 Step : 4260000 	 Average Reward : 177.2729
# Episode : 4719 	 Step : 4270000 	 Average Reward : 200.3768
# Episode : 4729 	 Step : 4280000 	 Average Reward : 179.473
# Episode : 4739 	 Step : 4290000 	 Average Reward : 201.8635
# Episode : 4750 	 Step : 4300000 	 Average Reward : 159.7403
# Episode : 4761 	 Step : 4310000 	 Average Reward : 182.1689
# Episode : 4771 	 Step : 4320000 	 Average Reward : 211.0018
# Episode : 4781 	 Step : 4330000 	 Average Reward : 207.468
# Episode : 4792 	 Step : 4340000 	 Average Reward : 166.9055
# Episode : 4803 	 Step : 4350000 	 Average Reward : 173.8591
# Episode : 4813 	 Step : 4360000 	 Average Reward : 203.9924
# Episode : 4823 	 Step : 4370000 	 Average Reward : 182.555
# Episode : 4834 	 Step : 4380000 	 Average Reward : 184.326
# Episode : 4844 	 Step : 4390000 	 Average Reward : 210.8819
# Episode : 4854 	 Step : 4400000 	 Average Reward : 211.7779
# Model Saved!!
# Episode : 4865 	 Step : 4410000 	 Average Reward : 187.6048
# Episode : 4875 	 Step : 4420000 	 Average Reward : 207.047
# Episode : 4885 	 Step : 4430000 	 Average Reward : 199.6437
# Episode : 4895 	 Step : 4440000 	 Average Reward : 217.2511
# Episode : 4905 	 Step : 4450000 	 Average Reward : 214.5102
# Episode : 4915 	 Step : 4460000 	 Average Reward : 198.6349
# Episode : 4926 	 Step : 4470000 	 Average Reward : 180.4534
# Episode : 4936 	 Step : 4480000 	 Average Reward : 219.4785
# Episode : 4946 	 Step : 4490000 	 Average Reward : 220.0038
# Episode : 4956 	 Step : 4500000 	 Average Reward : 186.732
# Episode : 4969 	 Step : 4510000 	 Average Reward : 139.2791
# Episode : 4979 	 Step : 4520000 	 Average Reward : 199.5792
# Episode : 4989 	 Step : 4530000 	 Average Reward : 214.5344
# Episode : 4999 	 Step : 4540000 	 Average Reward : 191.0706
# Episode : 5009 	 Step : 4550000 	 Average Reward : 218.5133
# Episode : 5020 	 Step : 4560000 	 Average Reward : 194.3316
# Episode : 5030 	 Step : 4570000 	 Average Reward : 219.6299
# Episode : 5041 	 Step : 4580000 	 Average Reward : 190.3354
# Episode : 5052 	 Step : 4590000 	 Average Reward : 161.7634
# Episode : 5062 	 Step : 4600000 	 Average Reward : 200.9131
# Model Saved!!
# Episode : 5074 	 Step : 4610000 	 Average Reward : 157.5975
# Episode : 5084 	 Step : 4620000 	 Average Reward : 180.283
# Episode : 5096 	 Step : 4630000 	 Average Reward : 153.0248
# Episode : 5106 	 Step : 4640000 	 Average Reward : 204.4829
# Episode : 5116 	 Step : 4650000 	 Average Reward : 210.6517
# Episode : 5126 	 Step : 4660000 	 Average Reward : 203.724
# Episode : 5137 	 Step : 4670000 	 Average Reward : 180.2386
# Episode : 5150 	 Step : 4680000 	 Average Reward : 146.0959
# Episode : 5160 	 Step : 4690000 	 Average Reward : 204.143
# Episode : 5171 	 Step : 4700000 	 Average Reward : 200.8584
# Episode : 5182 	 Step : 4710000 	 Average Reward : 194.5646
# Episode : 5192 	 Step : 4720000 	 Average Reward : 215.6275
# Episode : 5203 	 Step : 4730000 	 Average Reward : 178.3115
# Episode : 5213 	 Step : 4740000 	 Average Reward : 227.3912
# Episode : 5223 	 Step : 4750000 	 Average Reward : 209.1822
# Episode : 5234 	 Step : 4760000 	 Average Reward : 196.7147
# Episode : 5244 	 Step : 4770000 	 Average Reward : 232.5375
# Episode : 5255 	 Step : 4780000 	 Average Reward : 174.5557
# Episode : 5265 	 Step : 4790000 	 Average Reward : 227.6159
# Episode : 5277 	 Step : 4800000 	 Average Reward : 160.4934
# Model Saved!!
# Episode : 5288 	 Step : 4810000 	 Average Reward : 183.4419
# Episode : 5299 	 Step : 4820000 	 Average Reward : 210.1111
# Episode : 5309 	 Step : 4830000 	 Average Reward : 204.4579
# Episode : 5320 	 Step : 4840000 	 Average Reward : 217.5526
# Episode : 5330 	 Step : 4850000 	 Average Reward : 218.7211
# Episode : 5341 	 Step : 4860000 	 Average Reward : 179.3989
# Episode : 5351 	 Step : 4870000 	 Average Reward : 229.7794
# Episode : 5363 	 Step : 4880000 	 Average Reward : 176.4279
# Episode : 5373 	 Step : 4890000 	 Average Reward : 196.4403
# Episode : 5384 	 Step : 4900000 	 Average Reward : 211.0119
# Episode : 5394 	 Step : 4910000 	 Average Reward : 228.5492
# Episode : 5404 	 Step : 4920000 	 Average Reward : 217.4525
# Episode : 5414 	 Step : 4930000 	 Average Reward : 231.5694
# Episode : 5424 	 Step : 4940000 	 Average Reward : 235.7555
# Episode : 5436 	 Step : 4950000 	 Average Reward : 166.2225
# Episode : 5446 	 Step : 4960000 	 Average Reward : 229.1709
# Episode : 5456 	 Step : 4970000 	 Average Reward : 186.1571
# Episode : 5468 	 Step : 4980000 	 Average Reward : 166.5339
# Episode : 5478 	 Step : 4990000 	 Average Reward : 191.1715
# Episode : 5489 	 Step : 5000000 	 Average Reward : 217.1012
# Model Saved!!
# Episode : 5500 	 Step : 5010000 	 Average Reward : 189.8931
# Episode : 5510 	 Step : 5020000 	 Average Reward : 207.8854
# Episode : 5520 	 Step : 5030000 	 Average Reward : 230.5625
# Episode : 5531 	 Step : 5040000 	 Average Reward : 217.6827
# Episode : 5541 	 Step : 5050000 	 Average Reward : 233.6838
# Episode : 5551 	 Step : 5060000 	 Average Reward : 218.4456
# Episode : 5561 	 Step : 5070000 	 Average Reward : 204.4338
# Episode : 5571 	 Step : 5080000 	 Average Reward : 242.1383
# Episode : 5582 	 Step : 5090000 	 Average Reward : 210.5203
# Episode : 5593 	 Step : 5100000 	 Average Reward : 201.3296
# Episode : 5603 	 Step : 5110000 	 Average Reward : 211.5592
# Episode : 5614 	 Step : 5120000 	 Average Reward : 215.9253
# Episode : 5625 	 Step : 5130000 	 Average Reward : 201.7358
# Episode : 5635 	 Step : 5140000 	 Average Reward : 228.0753
# Episode : 5645 	 Step : 5150000 	 Average Reward : 238.6523
# Episode : 5655 	 Step : 5160000 	 Average Reward : 243.7983
# Episode : 5666 	 Step : 5170000 	 Average Reward : 192.7128
# Episode : 5677 	 Step : 5180000 	 Average Reward : 199.0717
# Episode : 5687 	 Step : 5190000 	 Average Reward : 204.5615
# Episode : 5697 	 Step : 5200000 	 Average Reward : 227.415
# Model Saved!!
# Episode : 5709 	 Step : 5210000 	 Average Reward : 183.7925
# Episode : 5720 	 Step : 5220000 	 Average Reward : 200.9536
# Episode : 5730 	 Step : 5230000 	 Average Reward : 233.2099
# Episode : 5740 	 Step : 5240000 	 Average Reward : 243.5036
# Episode : 5751 	 Step : 5250000 	 Average Reward : 198.8953
# Episode : 5761 	 Step : 5260000 	 Average Reward : 218.2975
# Episode : 5771 	 Step : 5270000 	 Average Reward : 240.3597
# Episode : 5784 	 Step : 5280000 	 Average Reward : 115.5816
# Episode : 5795 	 Step : 5290000 	 Average Reward : 210.2579
# Episode : 5805 	 Step : 5300000 	 Average Reward : 239.1618
# Episode : 5815 	 Step : 5310000 	 Average Reward : 242.941
# Episode : 5826 	 Step : 5320000 	 Average Reward : 194.3611
# Episode : 5836 	 Step : 5330000 	 Average Reward : 242.963
# Episode : 5847 	 Step : 5340000 	 Average Reward : 198.4198
# Episode : 5857 	 Step : 5350000 	 Average Reward : 242.0948
# Episode : 5867 	 Step : 5360000 	 Average Reward : 243.9496
# Episode : 5877 	 Step : 5370000 	 Average Reward : 239.2754
# Episode : 5888 	 Step : 5380000 	 Average Reward : 220.0104
# Episode : 5898 	 Step : 5390000 	 Average Reward : 199.1537
# Episode : 5909 	 Step : 5400000 	 Average Reward : 227.2162
# Model Saved!!
# Episode : 5919 	 Step : 5410000 	 Average Reward : 241.1326
# Episode : 5929 	 Step : 5420000 	 Average Reward : 225.8723
# Episode : 5939 	 Step : 5430000 	 Average Reward : 237.7406
# Episode : 5950 	 Step : 5440000 	 Average Reward : 211.2059
# Episode : 5961 	 Step : 5450000 	 Average Reward : 191.9433
# Episode : 5971 	 Step : 5460000 	 Average Reward : 193.72
# Episode : 5982 	 Step : 5470000 	 Average Reward : 198.3424
# Episode : 5994 	 Step : 5480000 	 Average Reward : 179.9015
# Episode : 6004 	 Step : 5490000 	 Average Reward : 224.0704
# Episode : 6014 	 Step : 5500000 	 Average Reward : 219.6467
# Episode : 6026 	 Step : 5510000 	 Average Reward : 196.0524
# Episode : 6036 	 Step : 5520000 	 Average Reward : 244.961
# Episode : 6046 	 Step : 5530000 	 Average Reward : 217.2932
# Episode : 6057 	 Step : 5540000 	 Average Reward : 198.7257
# Episode : 6069 	 Step : 5550000 	 Average Reward : 188.227
# Episode : 6079 	 Step : 5560000 	 Average Reward : 226.7964
# Episode : 6089 	 Step : 5570000 	 Average Reward : 244.1506
# Episode : 6099 	 Step : 5580000 	 Average Reward : 247.6871
# Episode : 6110 	 Step : 5590000 	 Average Reward : 229.121
# Episode : 6120 	 Step : 5600000 	 Average Reward : 232.1218
# Model Saved!!
# Episode : 6131 	 Step : 5610000 	 Average Reward : 185.2438
# Episode : 6141 	 Step : 5620000 	 Average Reward : 235.6492
# Episode : 6152 	 Step : 5630000 	 Average Reward : 216.3397
# Episode : 6162 	 Step : 5640000 	 Average Reward : 250.4917
# Episode : 6173 	 Step : 5650000 	 Average Reward : 180.7998
# Episode : 6183 	 Step : 5660000 	 Average Reward : 229.3285
# Episode : 6193 	 Step : 5670000 	 Average Reward : 217.5099
# Episode : 6203 	 Step : 5680000 	 Average Reward : 240.3479
# Episode : 6213 	 Step : 5690000 	 Average Reward : 242.9213
# Episode : 6223 	 Step : 5700000 	 Average Reward : 240.1697
# Episode : 6234 	 Step : 5710000 	 Average Reward : 201.3766
# Episode : 6244 	 Step : 5720000 	 Average Reward : 226.0827
# Episode : 6256 	 Step : 5730000 	 Average Reward : 204.3842
# Episode : 6266 	 Step : 5740000 	 Average Reward : 246.6778
# Episode : 6276 	 Step : 5750000 	 Average Reward : 212.2392
# Episode : 6286 	 Step : 5760000 	 Average Reward : 248.3464
# Episode : 6296 	 Step : 5770000 	 Average Reward : 250.2666
# Episode : 6307 	 Step : 5780000 	 Average Reward : 226.0791
# Episode : 6317 	 Step : 5790000 	 Average Reward : 248.934
# Episode : 6328 	 Step : 5800000 	 Average Reward : 204.4672
# Model Saved!!
# Episode : 6339 	 Step : 5810000 	 Average Reward : 182.8569
# Episode : 6350 	 Step : 5820000 	 Average Reward : 186.6732
# Episode : 6360 	 Step : 5830000 	 Average Reward : 244.8979
# Episode : 6370 	 Step : 5840000 	 Average Reward : 245.1427
# Episode : 6380 	 Step : 5850000 	 Average Reward : 246.9844
# Episode : 6391 	 Step : 5860000 	 Average Reward : 199.0179
# Episode : 6401 	 Step : 5870000 	 Average Reward : 249.319
# Episode : 6412 	 Step : 5880000 	 Average Reward : 213.0907
# Episode : 6422 	 Step : 5890000 	 Average Reward : 250.2003
# Episode : 6432 	 Step : 5900000 	 Average Reward : 250.6818
# Episode : 6443 	 Step : 5910000 	 Average Reward : 206.4267
# Episode : 6453 	 Step : 5920000 	 Average Reward : 249.7673
# Episode : 6463 	 Step : 5930000 	 Average Reward : 252.2599
# Episode : 6473 	 Step : 5940000 	 Average Reward : 251.8389
# Episode : 6483 	 Step : 5950000 	 Average Reward : 214.6877
# Episode : 6493 	 Step : 5960000 	 Average Reward : 250.6074
# Episode : 6504 	 Step : 5970000 	 Average Reward : 217.613
# Episode : 6515 	 Step : 5980000 	 Average Reward : 183.7055
# Episode : 6526 	 Step : 5990000 	 Average Reward : 199.1975
# Episode : 6536 	 Step : 6000000 	 Average Reward : 252.0948
# Model Saved!!
# Episode : 6546 	 Step : 6010000 	 Average Reward : 248.9548
# Episode : 6557 	 Step : 6020000 	 Average Reward : 194.5071
# Episode : 6567 	 Step : 6030000 	 Average Reward : 248.2654
# Episode : 6577 	 Step : 6040000 	 Average Reward : 247.7928
# Episode : 6588 	 Step : 6050000 	 Average Reward : 223.6839
# Episode : 6598 	 Step : 6060000 	 Average Reward : 251.2494
# Episode : 6608 	 Step : 6070000 	 Average Reward : 221.8705
# Episode : 6618 	 Step : 6080000 	 Average Reward : 247.8571
# Episode : 6629 	 Step : 6090000 	 Average Reward : 216.998
# Episode : 6639 	 Step : 6100000 	 Average Reward : 243.5485
# Episode : 6650 	 Step : 6110000 	 Average Reward : 216.9743
# Episode : 6660 	 Step : 6120000 	 Average Reward : 254.2104
# Episode : 6670 	 Step : 6130000 	 Average Reward : 225.5313
# Episode : 6681 	 Step : 6140000 	 Average Reward : 222.6905
# Episode : 6692 	 Step : 6150000 	 Average Reward : 204.7542
# Episode : 6702 	 Step : 6160000 	 Average Reward : 253.5411
# Episode : 6712 	 Step : 6170000 	 Average Reward : 249.615
# Episode : 6722 	 Step : 6180000 	 Average Reward : 248.0856
# Episode : 6733 	 Step : 6190000 	 Average Reward : 192.6523
# Episode : 6744 	 Step : 6200000 	 Average Reward : 237.7871
# Model Saved!!
# Episode : 6754 	 Step : 6210000 	 Average Reward : 235.5735
# Episode : 6764 	 Step : 6220000 	 Average Reward : 215.4985
# Episode : 6774 	 Step : 6230000 	 Average Reward : 252.553
# Episode : 6784 	 Step : 6240000 	 Average Reward : 252.472
# Episode : 6795 	 Step : 6250000 	 Average Reward : 210.1834
# Episode : 6805 	 Step : 6260000 	 Average Reward : 234.4669
# Episode : 6818 	 Step : 6270000 	 Average Reward : 179.7314
# Episode : 6829 	 Step : 6280000 	 Average Reward : 206.7928
# Episode : 6839 	 Step : 6290000 	 Average Reward : 213.0441
# Episode : 6851 	 Step : 6300000 	 Average Reward : 179.9104
# Episode : 6862 	 Step : 6310000 	 Average Reward : 180.8237
# Episode : 6873 	 Step : 6320000 	 Average Reward : 225.8646
# Episode : 6883 	 Step : 6330000 	 Average Reward : 250.931
# Episode : 6893 	 Step : 6340000 	 Average Reward : 234.4646
# Episode : 6904 	 Step : 6350000 	 Average Reward : 216.3648
# Episode : 6914 	 Step : 6360000 	 Average Reward : 252.5035
# Episode : 6924 	 Step : 6370000 	 Average Reward : 229.905
# Episode : 6935 	 Step : 6380000 	 Average Reward : 218.1528
# Episode : 6945 	 Step : 6390000 	 Average Reward : 253.1972
# Episode : 6955 	 Step : 6400000 	 Average Reward : 235.5513
# Model Saved!!
# Episode : 6965 	 Step : 6410000 	 Average Reward : 258.5733
# Episode : 6975 	 Step : 6420000 	 Average Reward : 253.2789
# Episode : 6985 	 Step : 6430000 	 Average Reward : 258.2376
# Episode : 6995 	 Step : 6440000 	 Average Reward : 256.9659
# Episode : 7005 	 Step : 6450000 	 Average Reward : 248.6242
# Episode : 7015 	 Step : 6460000 	 Average Reward : 254.5247
# Episode : 7025 	 Step : 6470000 	 Average Reward : 249.0986
# Episode : 7035 	 Step : 6480000 	 Average Reward : 257.2739
# Episode : 7046 	 Step : 6490000 	 Average Reward : 237.3667
# Episode : 7056 	 Step : 6500000 	 Average Reward : 255.5536
# Episode : 7067 	 Step : 6510000 	 Average Reward : 196.6611
# Episode : 7078 	 Step : 6520000 	 Average Reward : 218.5747
# Episode : 7088 	 Step : 6530000 	 Average Reward : 252.0328
# Episode : 7099 	 Step : 6540000 	 Average Reward : 219.7436
# Episode : 7109 	 Step : 6550000 	 Average Reward : 252.9146
# Episode : 7119 	 Step : 6560000 	 Average Reward : 218.3985
# Episode : 7130 	 Step : 6570000 	 Average Reward : 238.6158
# Episode : 7140 	 Step : 6580000 	 Average Reward : 221.0109
# Episode : 7151 	 Step : 6590000 	 Average Reward : 241.7016
# Episode : 7161 	 Step : 6600000 	 Average Reward : 253.7633
# Model Saved!!
# Episode : 7171 	 Step : 6610000 	 Average Reward : 236.9573
# Episode : 7181 	 Step : 6620000 	 Average Reward : 223.8827
# Episode : 7193 	 Step : 6630000 	 Average Reward : 202.612
# Episode : 7203 	 Step : 6640000 	 Average Reward : 216.662
# Episode : 7213 	 Step : 6650000 	 Average Reward : 255.3257
# Episode : 7224 	 Step : 6660000 	 Average Reward : 235.7408
# Episode : 7235 	 Step : 6670000 	 Average Reward : 219.9104
# Episode : 7245 	 Step : 6680000 	 Average Reward : 226.9119
# Episode : 7256 	 Step : 6690000 	 Average Reward : 221.7242
# Episode : 7267 	 Step : 6700000 	 Average Reward : 182.9956
# Episode : 7277 	 Step : 6710000 	 Average Reward : 236.3196
# Episode : 7288 	 Step : 6720000 	 Average Reward : 225.8651
# Episode : 7299 	 Step : 6730000 	 Average Reward : 186.9034
# Episode : 7309 	 Step : 6740000 	 Average Reward : 251.682
# Episode : 7322 	 Step : 6750000 	 Average Reward : 182.1414
# Episode : 7333 	 Step : 6760000 	 Average Reward : 201.8032
# Episode : 7345 	 Step : 6770000 	 Average Reward : 201.678
# Episode : 7355 	 Step : 6780000 	 Average Reward : 217.3009
# Episode : 7366 	 Step : 6790000 	 Average Reward : 213.692
# Episode : 7378 	 Step : 6800000 	 Average Reward : 207.5711
# Model Saved!!
# Episode : 7389 	 Step : 6810000 	 Average Reward : 182.6339
# Episode : 7399 	 Step : 6820000 	 Average Reward : 243.0818
# Episode : 7409 	 Step : 6830000 	 Average Reward : 252.0757
# Episode : 7420 	 Step : 6840000 	 Average Reward : 217.8321
# Episode : 7431 	 Step : 6850000 	 Average Reward : 214.5493
# Episode : 7441 	 Step : 6860000 	 Average Reward : 226.4253
# Episode : 7454 	 Step : 6870000 	 Average Reward : 150.7683
# Episode : 7466 	 Step : 6880000 	 Average Reward : 180.7976
# Episode : 7477 	 Step : 6890000 	 Average Reward : 209.1181
# Episode : 7488 	 Step : 6900000 	 Average Reward : 197.0292
# Episode : 7499 	 Step : 6910000 	 Average Reward : 200.6198
# Episode : 7512 	 Step : 6920000 	 Average Reward : 162.7771
# Episode : 7523 	 Step : 6930000 	 Average Reward : 215.3059
# Episode : 7533 	 Step : 6940000 	 Average Reward : 211.7428
# Episode : 7547 	 Step : 6950000 	 Average Reward : 142.5537
# Episode : 7559 	 Step : 6960000 	 Average Reward : 161.5373
# Episode : 7569 	 Step : 6970000 	 Average Reward : 206.0418
# Episode : 7580 	 Step : 6980000 	 Average Reward : 218.2246
# Episode : 7593 	 Step : 6990000 	 Average Reward : 152.0362
# Episode : 7604 	 Step : 7000000 	 Average Reward : 185.6699
# Model Saved!!
# Episode : 7616 	 Step : 7010000 	 Average Reward : 152.7583
# Episode : 7626 	 Step : 7020000 	 Average Reward : 243.2683
# Episode : 7636 	 Step : 7030000 	 Average Reward : 240.3868
# Episode : 7646 	 Step : 7040000 	 Average Reward : 236.6407
# Episode : 7657 	 Step : 7050000 	 Average Reward : 192.5019
# Episode : 7668 	 Step : 7060000 	 Average Reward : 194.437
# Episode : 7679 	 Step : 7070000 	 Average Reward : 207.7657
# Episode : 7690 	 Step : 7080000 	 Average Reward : 210.9369
# Episode : 7701 	 Step : 7090000 	 Average Reward : 200.6665
# Episode : 7712 	 Step : 7100000 	 Average Reward : 207.9279
# Episode : 7724 	 Step : 7110000 	 Average Reward : 173.9328
# Episode : 7734 	 Step : 7120000 	 Average Reward : 222.1599
# Episode : 7747 	 Step : 7130000 	 Average Reward : 161.8857
# Episode : 7758 	 Step : 7140000 	 Average Reward : 209.6687
# Episode : 7769 	 Step : 7150000 	 Average Reward : 192.3803
# Episode : 7783 	 Step : 7160000 	 Average Reward : 122.3331
# Episode : 7793 	 Step : 7170000 	 Average Reward : 253.5369
# Episode : 7804 	 Step : 7180000 	 Average Reward : 183.0391
# Episode : 7815 	 Step : 7190000 	 Average Reward : 217.6237
# Episode : 7827 	 Step : 7200000 	 Average Reward : 172.5328
# Model Saved!!
# Episode : 7839 	 Step : 7210000 	 Average Reward : 173.7496
# Episode : 7851 	 Step : 7220000 	 Average Reward : 198.7906
# Episode : 7863 	 Step : 7230000 	 Average Reward : 167.9348
# Episode : 7873 	 Step : 7240000 	 Average Reward : 224.5724
# Episode : 7884 	 Step : 7250000 	 Average Reward : 223.8345
# Episode : 7895 	 Step : 7260000 	 Average Reward : 179.525
# Episode : 7907 	 Step : 7270000 	 Average Reward : 193.7388
# Episode : 7918 	 Step : 7280000 	 Average Reward : 187.8013
# Episode : 7928 	 Step : 7290000 	 Average Reward : 227.4518
# Episode : 7940 	 Step : 7300000 	 Average Reward : 184.3254
# Episode : 7951 	 Step : 7310000 	 Average Reward : 189.9345
# Episode : 7963 	 Step : 7320000 	 Average Reward : 180.3472
# Episode : 7973 	 Step : 7330000 	 Average Reward : 233.3678
# Episode : 7985 	 Step : 7340000 	 Average Reward : 187.3884
# Episode : 7997 	 Step : 7350000 	 Average Reward : 194.9856
# Episode : 8007 	 Step : 7360000 	 Average Reward : 198.9867
# Episode : 8019 	 Step : 7370000 	 Average Reward : 199.5539
# Episode : 8030 	 Step : 7380000 	 Average Reward : 190.8188
# Episode : 8042 	 Step : 7390000 	 Average Reward : 164.4584
# Episode : 8054 	 Step : 7400000 	 Average Reward : 176.8047
# Model Saved!!
# Episode : 8064 	 Step : 7410000 	 Average Reward : 251.6127
# Episode : 8075 	 Step : 7420000 	 Average Reward : 206.0579
# Episode : 8086 	 Step : 7430000 	 Average Reward : 186.4523
# Episode : 8098 	 Step : 7440000 	 Average Reward : 166.407
# Episode : 8109 	 Step : 7450000 	 Average Reward : 225.3565
# Episode : 8119 	 Step : 7460000 	 Average Reward : 207.5832
# Episode : 8130 	 Step : 7470000 	 Average Reward : 231.5414
# Episode : 8140 	 Step : 7480000 	 Average Reward : 220.9022
# Episode : 8152 	 Step : 7490000 	 Average Reward : 199.7977
# Episode : 8162 	 Step : 7500000 	 Average Reward : 251.0579
# Episode : 8174 	 Step : 7510000 	 Average Reward : 186.6036
# Episode : 8185 	 Step : 7520000 	 Average Reward : 179.2765
# Episode : 8197 	 Step : 7530000 	 Average Reward : 175.0673
# Episode : 8208 	 Step : 7540000 	 Average Reward : 186.8862
# Episode : 8220 	 Step : 7550000 	 Average Reward : 197.8422
# Episode : 8231 	 Step : 7560000 	 Average Reward : 180.1303
# Episode : 8243 	 Step : 7570000 	 Average Reward : 178.3957
# Episode : 8254 	 Step : 7580000 	 Average Reward : 184.9253
# Episode : 8265 	 Step : 7590000 	 Average Reward : 222.1653
# Episode : 8276 	 Step : 7600000 	 Average Reward : 208.8042
# Model Saved!!
# Episode : 8286 	 Step : 7610000 	 Average Reward : 240.8267
# Episode : 8296 	 Step : 7620000 	 Average Reward : 253.7965
# Episode : 8306 	 Step : 7630000 	 Average Reward : 218.9405
# Episode : 8318 	 Step : 7640000 	 Average Reward : 187.4287
# Episode : 8329 	 Step : 7650000 	 Average Reward : 194.9143
# Episode : 8341 	 Step : 7660000 	 Average Reward : 154.604
# Episode : 8353 	 Step : 7670000 	 Average Reward : 198.592
# Episode : 8364 	 Step : 7680000 	 Average Reward : 156.0622
# Episode : 8376 	 Step : 7690000 	 Average Reward : 171.0985
# Episode : 8387 	 Step : 7700000 	 Average Reward : 208.8168
# Episode : 8398 	 Step : 7710000 	 Average Reward : 217.656
# Episode : 8408 	 Step : 7720000 	 Average Reward : 252.6579
# Episode : 8418 	 Step : 7730000 	 Average Reward : 222.3132
# Episode : 8428 	 Step : 7740000 	 Average Reward : 246.6429
# Episode : 8439 	 Step : 7750000 	 Average Reward : 206.7576
# Episode : 8450 	 Step : 7760000 	 Average Reward : 225.6094
# Episode : 8460 	 Step : 7770000 	 Average Reward : 257.182
# Episode : 8471 	 Step : 7780000 	 Average Reward : 202.0817
# Episode : 8482 	 Step : 7790000 	 Average Reward : 237.3693
# Episode : 8493 	 Step : 7800000 	 Average Reward : 181.3509
# Model Saved!!
# Episode : 8504 	 Step : 7810000 	 Average Reward : 225.2496
# Episode : 8514 	 Step : 7820000 	 Average Reward : 253.2869
# Episode : 8524 	 Step : 7830000 	 Average Reward : 211.7359
# Episode : 8535 	 Step : 7840000 	 Average Reward : 216.3843
# Episode : 8545 	 Step : 7850000 	 Average Reward : 231.6216
# Episode : 8556 	 Step : 7860000 	 Average Reward : 211.7171
# Episode : 8566 	 Step : 7870000 	 Average Reward : 225.379
# Episode : 8579 	 Step : 7880000 	 Average Reward : 171.5461
# Episode : 8590 	 Step : 7890000 	 Average Reward : 184.4224
# Episode : 8601 	 Step : 7900000 	 Average Reward : 238.6408
# Episode : 8613 	 Step : 7910000 	 Average Reward : 168.3669
# Episode : 8625 	 Step : 7920000 	 Average Reward : 176.5455
# Episode : 8636 	 Step : 7930000 	 Average Reward : 220.1826
# Episode : 8648 	 Step : 7940000 	 Average Reward : 185.7204
# Episode : 8659 	 Step : 7950000 	 Average Reward : 195.1392
# Episode : 8669 	 Step : 7960000 	 Average Reward : 203.5615
# Episode : 8685 	 Step : 7970000 	 Average Reward : 110.6026
# Episode : 8696 	 Step : 7980000 	 Average Reward : 228.1725
# Episode : 8707 	 Step : 7990000 	 Average Reward : 169.3175
# Episode : 8720 	 Step : 8000000 	 Average Reward : 142.3298
# Model Saved!!
# Episode : 8733 	 Step : 8010000 	 Average Reward : 164.5152
# Episode : 8744 	 Step : 8020000 	 Average Reward : 194.7487
# Episode : 8756 	 Step : 8030000 	 Average Reward : 178.325
# Episode : 8770 	 Step : 8040000 	 Average Reward : 116.1862
# Episode : 8784 	 Step : 8050000 	 Average Reward : 147.4639
# Episode : 8797 	 Step : 8060000 	 Average Reward : 143.3627
# Episode : 8810 	 Step : 8070000 	 Average Reward : 175.4581
# Episode : 8823 	 Step : 8080000 	 Average Reward : 156.5146
# Episode : 8836 	 Step : 8090000 	 Average Reward : 138.1969
# Episode : 8850 	 Step : 8100000 	 Average Reward : 119.2788
# Episode : 8862 	 Step : 8110000 	 Average Reward : 164.8155
# Episode : 8875 	 Step : 8120000 	 Average Reward : 182.6143
# Episode : 8887 	 Step : 8130000 	 Average Reward : 161.5374
# Episode : 8897 	 Step : 8140000 	 Average Reward : 237.5654
# Episode : 8910 	 Step : 8150000 	 Average Reward : 119.6897
# Episode : 8922 	 Step : 8160000 	 Average Reward : 176.6323
# Episode : 8935 	 Step : 8170000 	 Average Reward : 171.2272
# Episode : 8945 	 Step : 8180000 	 Average Reward : 235.6106
# Episode : 8958 	 Step : 8190000 	 Average Reward : 134.6704
# Episode : 8971 	 Step : 8200000 	 Average Reward : 158.9822
# Model Saved!!
# Episode : 8987 	 Step : 8210000 	 Average Reward : 100.1972
# Episode : 9002 	 Step : 8220000 	 Average Reward : 104.1818
# Episode : 9014 	 Step : 8230000 	 Average Reward : 184.6941
# Episode : 9027 	 Step : 8240000 	 Average Reward : 165.8289
# Episode : 9044 	 Step : 8250000 	 Average Reward : 68.6379
# Episode : 9057 	 Step : 8260000 	 Average Reward : 144.1641
# Episode : 9071 	 Step : 8270000 	 Average Reward : 142.7372
# Episode : 9083 	 Step : 8280000 	 Average Reward : 172.9822
# Episode : 9095 	 Step : 8290000 	 Average Reward : 193.5703
# Episode : 9106 	 Step : 8300000 	 Average Reward : 179.8348
# Episode : 9121 	 Step : 8310000 	 Average Reward : 116.1391
# Episode : 9134 	 Step : 8320000 	 Average Reward : 142.7291
# Episode : 9146 	 Step : 8330000 	 Average Reward : 176.4495
# Episode : 9157 	 Step : 8340000 	 Average Reward : 197.678
# Episode : 9169 	 Step : 8350000 	 Average Reward : 182.5756
# Episode : 9181 	 Step : 8360000 	 Average Reward : 158.1422
# Episode : 9194 	 Step : 8370000 	 Average Reward : 156.1053
# Episode : 9204 	 Step : 8380000 	 Average Reward : 218.8602
# Episode : 9215 	 Step : 8390000 	 Average Reward : 232.5215
# Episode : 9225 	 Step : 8400000 	 Average Reward : 248.6795
# Model Saved!!
# Episode : 9236 	 Step : 8410000 	 Average Reward : 197.115
# Episode : 9246 	 Step : 8420000 	 Average Reward : 223.0094
# Episode : 9261 	 Step : 8430000 	 Average Reward : 111.9784
# Episode : 9271 	 Step : 8440000 	 Average Reward : 223.3243
# Episode : 9282 	 Step : 8450000 	 Average Reward : 213.0606
# Episode : 9295 	 Step : 8460000 	 Average Reward : 155.8232
# Episode : 9307 	 Step : 8470000 	 Average Reward : 173.0814
# Episode : 9319 	 Step : 8480000 	 Average Reward : 170.0667
# Episode : 9330 	 Step : 8490000 	 Average Reward : 192.1862
# Episode : 9343 	 Step : 8500000 	 Average Reward : 155.1133
# Episode : 9355 	 Step : 8510000 	 Average Reward : 166.003
# Episode : 9368 	 Step : 8520000 	 Average Reward : 165.1601
# Episode : 9381 	 Step : 8530000 	 Average Reward : 170.2019
# Episode : 9393 	 Step : 8540000 	 Average Reward : 160.5495
# Episode : 9407 	 Step : 8550000 	 Average Reward : 135.418
# Episode : 9419 	 Step : 8560000 	 Average Reward : 161.0002
# Episode : 9432 	 Step : 8570000 	 Average Reward : 143.9608
# Episode : 9445 	 Step : 8580000 	 Average Reward : 134.2256
# Episode : 9457 	 Step : 8590000 	 Average Reward : 184.0902
# Episode : 9468 	 Step : 8600000 	 Average Reward : 209.8609
# Model Saved!!
# Episode : 9479 	 Step : 8610000 	 Average Reward : 199.0907
# Episode : 9490 	 Step : 8620000 	 Average Reward : 185.3245
# Episode : 9502 	 Step : 8630000 	 Average Reward : 195.203
# Episode : 9513 	 Step : 8640000 	 Average Reward : 201.0683
# Episode : 9525 	 Step : 8650000 	 Average Reward : 171.8816
# Episode : 9537 	 Step : 8660000 	 Average Reward : 152.3801
# Episode : 9548 	 Step : 8670000 	 Average Reward : 214.861
# Episode : 9558 	 Step : 8680000 	 Average Reward : 246.7915
# Episode : 9570 	 Step : 8690000 	 Average Reward : 178.0878
# Episode : 9581 	 Step : 8700000 	 Average Reward : 214.6732
# Episode : 9592 	 Step : 8710000 	 Average Reward : 201.8072
# Episode : 9602 	 Step : 8720000 	 Average Reward : 248.0487
# Episode : 9613 	 Step : 8730000 	 Average Reward : 195.7521
# Episode : 9623 	 Step : 8740000 	 Average Reward : 232.5039
# Episode : 9633 	 Step : 8750000 	 Average Reward : 247.1633
# Episode : 9646 	 Step : 8760000 	 Average Reward : 143.5051
# Episode : 9656 	 Step : 8770000 	 Average Reward : 248.7511
# Episode : 9668 	 Step : 8780000 	 Average Reward : 180.6893
# Episode : 9680 	 Step : 8790000 	 Average Reward : 185.8486
# Episode : 9690 	 Step : 8800000 	 Average Reward : 222.0675
# Model Saved!!
# Episode : 9701 	 Step : 8810000 	 Average Reward : 213.7578
# Episode : 9712 	 Step : 8820000 	 Average Reward : 204.503
# Episode : 9724 	 Step : 8830000 	 Average Reward : 178.2359
# Episode : 9735 	 Step : 8840000 	 Average Reward : 192.8112
# Episode : 9745 	 Step : 8850000 	 Average Reward : 253.6226
# Episode : 9757 	 Step : 8860000 	 Average Reward : 187.1646
# Episode : 9769 	 Step : 8870000 	 Average Reward : 170.5946
# Episode : 9781 	 Step : 8880000 	 Average Reward : 179.3275
# Episode : 9791 	 Step : 8890000 	 Average Reward : 206.3404
# Episode : 9803 	 Step : 8900000 	 Average Reward : 198.1591
# Episode : 9814 	 Step : 8910000 	 Average Reward : 214.066
# Episode : 9826 	 Step : 8920000 	 Average Reward : 183.8784
# Episode : 9837 	 Step : 8930000 	 Average Reward : 195.74
# Episode : 9850 	 Step : 8940000 	 Average Reward : 130.5341
# Episode : 9863 	 Step : 8950000 	 Average Reward : 160.5044
# Episode : 9873 	 Step : 8960000 	 Average Reward : 235.6273
# Episode : 9885 	 Step : 8970000 	 Average Reward : 169.71
# Episode : 9896 	 Step : 8980000 	 Average Reward : 211.8017
# Episode : 9909 	 Step : 8990000 	 Average Reward : 155.5488
# Episode : 9923 	 Step : 9000000 	 Average Reward : 144.811
# Model Saved!!
# Episode : 9936 	 Step : 9010000 	 Average Reward : 150.4818
# Episode : 9951 	 Step : 9020000 	 Average Reward : 106.0232
# Episode : 9966 	 Step : 9030000 	 Average Reward : 113.5505
# Episode : 9981 	 Step : 9040000 	 Average Reward : 113.9958
# Episode : 9997 	 Step : 9050000 	 Average Reward : 110.8699
# Episode : 10014 	 Step : 9060000 	 Average Reward : 85.8487
# Episode : 10027 	 Step : 9070000 	 Average Reward : 146.4784
# Episode : 10039 	 Step : 9080000 	 Average Reward : 170.9581
# Episode : 10051 	 Step : 9090000 	 Average Reward : 185.3662
# Episode : 10063 	 Step : 9100000 	 Average Reward : 167.0546
# Episode : 10076 	 Step : 9110000 	 Average Reward : 151.5275
# Episode : 10090 	 Step : 9120000 	 Average Reward : 147.3533
# Episode : 10101 	 Step : 9130000 	 Average Reward : 193.1375
# Episode : 10114 	 Step : 9140000 	 Average Reward : 172.5264
# Episode : 10125 	 Step : 9150000 	 Average Reward : 199.4967
# Episode : 10136 	 Step : 9160000 	 Average Reward : 212.6283
# Episode : 10147 	 Step : 9170000 	 Average Reward : 205.2338
# Episode : 10160 	 Step : 9180000 	 Average Reward : 157.2908
# Episode : 10171 	 Step : 9190000 	 Average Reward : 217.6622
# Episode : 10182 	 Step : 9200000 	 Average Reward : 188.238
# Model Saved!!
# Episode : 10192 	 Step : 9210000 	 Average Reward : 250.5124
# Episode : 10204 	 Step : 9220000 	 Average Reward : 176.949
# Episode : 10214 	 Step : 9230000 	 Average Reward : 225.7209
# Episode : 10224 	 Step : 9240000 	 Average Reward : 249.4695
# Episode : 10237 	 Step : 9250000 	 Average Reward : 143.9191
# Episode : 10247 	 Step : 9260000 	 Average Reward : 245.8021
# Episode : 10258 	 Step : 9270000 	 Average Reward : 210.7119
# Episode : 10274 	 Step : 9280000 	 Average Reward : 98.8728
# Episode : 10288 	 Step : 9290000 	 Average Reward : 120.3716
# Episode : 10299 	 Step : 9300000 	 Average Reward : 212.372
# Episode : 10312 	 Step : 9310000 	 Average Reward : 157.6255
# Episode : 10324 	 Step : 9320000 	 Average Reward : 171.7248
# Episode : 10336 	 Step : 9330000 	 Average Reward : 189.2972
# Episode : 10353 	 Step : 9340000 	 Average Reward : 87.4972
# Episode : 10363 	 Step : 9350000 	 Average Reward : 228.6524
# Episode : 10375 	 Step : 9360000 	 Average Reward : 173.6582
# Episode : 10389 	 Step : 9370000 	 Average Reward : 131.838
# Episode : 10402 	 Step : 9380000 	 Average Reward : 166.0441
# Episode : 10416 	 Step : 9390000 	 Average Reward : 114.5029
# Episode : 10426 	 Step : 9400000 	 Average Reward : 207.7335
# Model Saved!!
# Episode : 10437 	 Step : 9410000 	 Average Reward : 238.1026
# Episode : 10450 	 Step : 9420000 	 Average Reward : 138.2717
# Episode : 10462 	 Step : 9430000 	 Average Reward : 167.3358
# Episode : 10472 	 Step : 9440000 	 Average Reward : 217.4989
# Episode : 10484 	 Step : 9450000 	 Average Reward : 188.6416
# Episode : 10496 	 Step : 9460000 	 Average Reward : 171.5366
# Episode : 10507 	 Step : 9470000 	 Average Reward : 203.9701
# Episode : 10519 	 Step : 9480000 	 Average Reward : 183.0303
# Episode : 10531 	 Step : 9490000 	 Average Reward : 176.2749
# Episode : 10544 	 Step : 9500000 	 Average Reward : 168.5224
# Episode : 10556 	 Step : 9510000 	 Average Reward : 185.9212
# Episode : 10568 	 Step : 9520000 	 Average Reward : 175.8134
# Episode : 10578 	 Step : 9530000 	 Average Reward : 231.0032
# Episode : 10590 	 Step : 9540000 	 Average Reward : 157.8911
# Episode : 10602 	 Step : 9550000 	 Average Reward : 163.2657
# Episode : 10613 	 Step : 9560000 	 Average Reward : 214.8169
# Episode : 10623 	 Step : 9570000 	 Average Reward : 243.4991
# Episode : 10636 	 Step : 9580000 	 Average Reward : 160.5544
# Episode : 10647 	 Step : 9590000 	 Average Reward : 179.4603
# Episode : 10658 	 Step : 9600000 	 Average Reward : 204.4598
# Model Saved!!
# Episode : 10670 	 Step : 9610000 	 Average Reward : 181.9604
# Episode : 10684 	 Step : 9620000 	 Average Reward : 129.0783
# Episode : 10696 	 Step : 9630000 	 Average Reward : 165.0451
# Episode : 10708 	 Step : 9640000 	 Average Reward : 186.834
# Episode : 10718 	 Step : 9650000 	 Average Reward : 219.016
# Episode : 10730 	 Step : 9660000 	 Average Reward : 204.7246
# Episode : 10740 	 Step : 9670000 	 Average Reward : 250.7522
# Episode : 10751 	 Step : 9680000 	 Average Reward : 172.5867
# Episode : 10763 	 Step : 9690000 	 Average Reward : 190.6653
# Episode : 10774 	 Step : 9700000 	 Average Reward : 194.1601
# Episode : 10788 	 Step : 9710000 	 Average Reward : 134.2335
# Episode : 10799 	 Step : 9720000 	 Average Reward : 206.6277
# Episode : 10812 	 Step : 9730000 	 Average Reward : 162.6386
# Episode : 10824 	 Step : 9740000 	 Average Reward : 163.3763
# Episode : 10836 	 Step : 9750000 	 Average Reward : 191.9246
# Episode : 10846 	 Step : 9760000 	 Average Reward : 248.8712
# Episode : 10860 	 Step : 9770000 	 Average Reward : 148.8772
# Episode : 10875 	 Step : 9780000 	 Average Reward : 108.3442
# Episode : 10888 	 Step : 9790000 	 Average Reward : 140.9768
# Episode : 10900 	 Step : 9800000 	 Average Reward : 174.5317
# Model Saved!!
# Episode : 10912 	 Step : 9810000 	 Average Reward : 201.2943
# Episode : 10925 	 Step : 9820000 	 Average Reward : 122.4745
# Episode : 10937 	 Step : 9830000 	 Average Reward : 191.7585
# Episode : 10947 	 Step : 9840000 	 Average Reward : 232.7611
# Episode : 10958 	 Step : 9850000 	 Average Reward : 218.7251
# Episode : 10971 	 Step : 9860000 	 Average Reward : 126.4879
# Episode : 10984 	 Step : 9870000 	 Average Reward : 158.0713
# Episode : 10999 	 Step : 9880000 	 Average Reward : 120.0948
# Episode : 11016 	 Step : 9890000 	 Average Reward : 54.328
# Episode : 11031 	 Step : 9900000 	 Average Reward : 119.7941
# Episode : 11045 	 Step : 9910000 	 Average Reward : 122.5562
# Episode : 11058 	 Step : 9920000 	 Average Reward : 119.2396
# Episode : 11072 	 Step : 9930000 	 Average Reward : 150.3632
# Episode : 11084 	 Step : 9940000 	 Average Reward : 162.2976
# Episode : 11097 	 Step : 9950000 	 Average Reward : 139.8264
# Episode : 11107 	 Step : 9960000 	 Average Reward : 245.3967
# Episode : 11118 	 Step : 9970000 	 Average Reward : 217.072
# Episode : 11133 	 Step : 9980000 	 Average Reward : 88.9818
# Episode : 11144 	 Step : 9990000 	 Average Reward : 180.1357
# Episode : 11154 	 Step : 10000000 	 Average Reward : 225.7152
# Model Saved!!
